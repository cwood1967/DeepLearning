# %%
import sys
sys.path.append('/media/cjw/PythonLib/cjwdeeplearning')

import autoencoder.adversarial_cluster as aaec
import autoencoder.adversarial as aae
from matplotlib import pyplot as plt
# %matplotlib inline
# Out:
# /home/cjw/anaconda3/envs/deep/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
esize = [(64,7), (128, 5), (256,3), (512,3), (1024, 3), (2048,3), (4096, 3)]
dsize = list(reversed(esize))

params =dict()

params['nclusters'] = 28
params['width'] = 256
params['height'] = 256
params['nchannels'] = 1
params['channels'] = [0]
params['nepochs'] = 40
params['batchsize'] = 1
params['learning_rate'] = 0.0005
params['restore'] = False
params['latent_size'] = 1024
params['enc_sizes'] = esize 
params['dec_sizes'] = dsize
params['droprate'] = 0.85
params['stdev'] = 0.04
params['denoise'] = False
params['slam'] = 0

datadir = "/media/cjw/Data/"

# %%
t = aae.training(params, datadir, "nuclei_0")
t.train(gpu=True, display=True, display_int=100, report_int=100, niterations=10001)

#aae.train(1001, display=True, display_int=500, report_int=50,title="Adver_try3")
# Out:
# Using data from: /media/cjw/Data/
# Saving checkpoints to: /media/cjw/Data/cyto/Checkpoints/2018-10-04-17-06-21_nuclei_0/checkpoint-2018-10-04-17-06-21/autoencoder-1024x
# Encoder True
# Tensor("Placeholder:0", shape=(?, 1024, 1024, 1), dtype=float32) (?, 1024, 1024, 1)
# Tensor("encoder/latent_space/BiasAdd:0", shape=(?, 1024), dtype=float32)
# isize:  8 1024
# Tensor("decoder/decoder_out/BiasAdd:0", shape=(?, 1024, 1024, 1), dtype=float32)
# <tf.Variable 'encoder/filter_00/kernel:0' shape=(7, 7, 1, 64) dtype=float32_ref>
# <tf.Variable 'encoder/filter_00/bias:0' shape=(64,) dtype=float32_ref>
# <tf.Variable 'encoder/filter_01/kernel:0' shape=(5, 5, 64, 128) dtype=float32_ref>
# <tf.Variable 'encoder/filter_01/bias:0' shape=(128,) dtype=float32_ref>
# <tf.Variable 'encoder/filter_02/kernel:0' shape=(3, 3, 128, 256) dtype=float32_ref>
# <tf.Variable 'encoder/filter_02/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'encoder/filter_03/kernel:0' shape=(3, 3, 256, 512) dtype=float32_ref>
# <tf.Variable 'encoder/filter_03/bias:0' shape=(512,) dtype=float32_ref>
# <tf.Variable 'encoder/filter_04/kernel:0' shape=(3, 3, 512, 1024) dtype=float32_ref>
# <tf.Variable 'encoder/filter_04/bias:0' shape=(1024,) dtype=float32_ref>
# <tf.Variable 'encoder/filter_05/kernel:0' shape=(3, 3, 1024, 2048) dtype=float32_ref>
# <tf.Variable 'encoder/filter_05/bias:0' shape=(2048,) dtype=float32_ref>
# <tf.Variable 'encoder/filter_06/kernel:0' shape=(3, 3, 2048, 4096) dtype=float32_ref>
# <tf.Variable 'encoder/filter_06/bias:0' shape=(4096,) dtype=float32_ref>
# <tf.Variable 'encoder/latent_space/kernel:0' shape=(262144, 1024) dtype=float32_ref>
# <tf.Variable 'encoder/latent_space/bias:0' shape=(1024,) dtype=float32_ref>
# <tf.Variable 'decoder/dense/kernel:0' shape=(1024, 262144) dtype=float32_ref>
# <tf.Variable 'decoder/dense/bias:0' shape=(262144,) dtype=float32_ref>
# <tf.Variable 'decoder/conv2d_transpose/kernel:0' shape=(3, 3, 2048, 4096) dtype=float32_ref>
# <tf.Variable 'decoder/conv2d_transpose/bias:0' shape=(2048,) dtype=float32_ref>
# <tf.Variable 'decoder/conv2d_transpose_1/kernel:0' shape=(3, 3, 1024, 2048) dtype=float32_ref>
# <tf.Variable 'decoder/conv2d_transpose_1/bias:0' shape=(1024,) dtype=float32_ref>
# <tf.Variable 'decoder/conv2d_transpose_2/kernel:0' shape=(3, 3, 512, 1024) dtype=float32_ref>
# <tf.Variable 'decoder/conv2d_transpose_2/bias:0' shape=(512,) dtype=float32_ref>
# <tf.Variable 'decoder/conv2d_transpose_3/kernel:0' shape=(3, 3, 256, 512) dtype=float32_ref>
# <tf.Variable 'decoder/conv2d_transpose_3/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'decoder/conv2d_transpose_4/kernel:0' shape=(5, 5, 128, 256) dtype=float32_ref>
# <tf.Variable 'decoder/conv2d_transpose_4/bias:0' shape=(128,) dtype=float32_ref>
# <tf.Variable 'decoder/conv2d_transpose_5/kernel:0' shape=(7, 7, 64, 128) dtype=float32_ref>
# <tf.Variable 'decoder/conv2d_transpose_5/bias:0' shape=(64,) dtype=float32_ref>
# <tf.Variable 'decoder/decoder_out/kernel:0' shape=(5, 5, 1, 64) dtype=float32_ref>
# <tf.Variable 'decoder/decoder_out/bias:0' shape=(1,) dtype=float32_ref>
# (64, 1024, 1024, 1) (64, 1024, 1024, 1) (64, 1, 1, 1) (64, 1024, 1024, 1)
# 0 29.270214 129.95097 3398701600.0
# display
# 100 30.299702 5.5522156 40117890.0
# display
# 200 4.5302167 9.364861 5730258.0
# display
# 300 2.0202765 0.544429 3384574.2
# display
# 400 1.7829324 1.5539032 1724758.2
# display
# 500 1.8597308 0.59882206 1600828.8
# display
# 600 1.8466059 0.62163305 1524582.5
# display
# 700 1.6461861 0.7097793 1353189.1
# display
# 800 1.4000435 0.9380317 1213293.9
# display
# 900 1.6901108 0.6936418 1160655.2
# display
# 1000 1.3648398 0.8584552 1152520.0
# display
# 1100 1.3752595 0.7628637 1115213.0
# display
# 1200 1.6417749 0.5933504 1081126.1
# display
# 1300 1.5213387 0.6401717 1069924.0
# display
# 1400 1.5464756 0.6187309 1100076.2
# display
# 1500 1.4574142 0.7055295 1095252.6
# display
# 1600 1.5168285 0.61835694 1067309.5
# display
# 1700 1.3437681 0.6787925 1091961.1
# display
# 1800 1.5392914 0.6090636 1068794.5
# display
# 1900 1.5030895 0.56559813 1070061.1
# display
# 2000 1.6908355 0.55677986 1059504.2
# display
# 2100 1.5469575 0.589558 1061570.8
# display
# 2200 1.5545291 0.61759037 1065130.9
# display
# 2300 1.608425 0.6340369 1081250.8
# display
# 2400 1.6070887 0.5698914 1065472.8
# display
# 2500 1.4441414 0.68249106 1072341.8
# display
# 2600 1.493305 0.69537604 1079952.4
# display
# 2700 1.472573 0.685577 1092645.8
# display
# 2800 1.5217537 0.63115746 1089081.5
# display
# 2900 1.4147089 0.6745573 1092282.1
# display
# 3000 1.3444631 0.6675058 1095663.0
# display
# 3100 1.3675858 0.6505228 1095227.2
# display
# 3200 1.2609496 0.79927486 1071089.2
# display
# 3300 nan nan nan
# display
# /home/cjw/anaconda3/envs/deep/lib/python3.6/site-packages/numpy/core/_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# /home/cjw/anaconda3/envs/deep/lib/python3.6/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-137619458205> in <module>()
#       1 t = aae.training(params, datadir, "nuclei_0")
# ----> 2 t.train(gpu=True, display=True, display_int=100, report_int=100, niterations=10001)
#       3
#       4 #aae.train(1001, display=True, display_int=500, report_int=50,title="Adver_try3")
#
# /media/cjw/PythonLib/cjwdeeplearning/autoencoder/adversarial.py in train(self, gpu, display, display_int, report_int, niterations)
#     270                     ri = 0
#     271
# --> 272                 self.idisplay(test_image, batch_z)
#     273
#     274             if i % 1000 == 0:
#
# /media/cjw/PythonLib/cjwdeeplearning/autoencoder/adversarial.py in idisplay(self, test_image, batch_z)
#     311         plt.hist(batch_z.reshape((-1)), bins=25)
#     312         plt.subplot(2,3,6)
# --> 313         plt.hist(xspace.reshape((-1)), bins=25)
#     314         plt.show()
#     315
#
# ~/anaconda3/envs/deep/lib/python3.6/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, hold, data, **kwargs)
#    3135                       histtype=histtype, align=align, orientation=orientation,
#    3136                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3137                       stacked=stacked, normed=normed, data=data, **kwargs)
#    3138     finally:
#    3139         ax._hold = washold
#
# ~/anaconda3/envs/deep/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/envs/deep/lib/python3.6/site-packages/matplotlib/axes/_axes.py in hist(***failed resolving arguments***)
#    6637             # this will automatically overwrite bins,
#    6638             # so that each histogram uses the same bins
# -> 6639             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6640             m = m.astype(float)  # causes problems later if it's an int
#    6641             if mlast is None:
#
# ~/anaconda3/envs/deep/lib/python3.6/site-packages/numpy/lib/function_base.py in histogram(a, bins, range, normed, weights, density)
#     665     if first_edge > last_edge:
#     666         raise ValueError(
# --> 667             'max must be larger than min in range parameter.')
#     668     if not np.all(np.isfinite([first_edge, last_edge])):
#     669         raise ValueError(
#
# ValueError: max must be larger than min in range parameter.
# /home/cjw/anaconda3/envs/deep/lib/python3.6/site-packages/matplotlib/image.py:405: UserWarning: Warning: converting a masked element to nan.
#   dv = (np.float64(self.norm.vmax) -
# /home/cjw/anaconda3/envs/deep/lib/python3.6/site-packages/matplotlib/image.py:406: UserWarning: Warning: converting a masked element to nan.
#   np.float64(self.norm.vmin))
# /home/cjw/anaconda3/envs/deep/lib/python3.6/site-packages/matplotlib/image.py:413: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# /home/cjw/anaconda3/envs/deep/lib/python3.6/site-packages/matplotlib/image.py:418: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# /home/cjw/anaconda3/envs/deep/lib/python3.6/site-packages/matplotlib/colors.py:916: UserWarning: Warning: converting a masked element to nan.
#   dtype = np.min_scalar_type(value)
# /home/cjw/anaconda3/envs/deep/lib/python3.6/site-packages/numpy/ma/core.py:716: UserWarning: Warning: converting a masked element to nan.
#   data = np.array(a, copy=False, subok=subok)

# %%
import autoencoder.cluster_layer as cl

# %%
nc = t.params['nclusters']
m = t.params['latent_size']
Z = t.encoder.eval({t.images:t.get_batch(2400)}, session=t.sess)
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=nc, n_init=20)
yp = kmeans.fit_predict(Z)
ypp = np.copy(yp)
c = cl.cluster_layer(nc, kmeans.cluster_centers_)
ca = c.apply(t.encoder)
#c.build((params['batchsize'], m))

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib notebook
z = t.encoder.eval({t.images:t.get_batch(2400)}, session=t.sess)
r = t.decoder.eval({t.encoder:z}, session=t.sess)
print(g.shape)
plt.subplot(2,1,1)
plt.plot(z[0])
plt.subplot(2,1,2)
plt.imshow(r[0,:,:,0])
# Out:
# (1, 256)
# <img src="data:image/png;base64,..." width="432">

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=16, n_init=20)
km = kmeans.fit_predict(z)
cx = kmeans.cluster_centers_

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, perplexity=10, learning_rate=80, metric='cosine').fit_transform(z)

# %%
print(tsne.shape)
# %matplotlib notebook
f = plt.figure(figsize=(6,6))
plt.scatter(tsne[:,0], tsne[:,1], 5, km, cmap='tab20_r')
plt.show()
# Out:
# (2400, 2)
# <img src="data:image/png;base64,..." width="432">

# %%
t.saver.restore(t.sess,
                "/media/cjw/Data/cyto/Checkpoints/2018-09-05-10-58-21_idec_try_3/checkpoint-2018-09-05-10-58-21/autoencoder-256x-16000")
# Out:
# INFO:tensorflow:Restoring parameters from /media/cjw/Data/cyto/Checkpoints/2018-09-05-10-58-21_idec_try_3/checkpoint-2018-09-05-10-58-21/autoencoder-256x-16000

# %%
t.encoder
# Out:
# <tf.Tensor 'encoder/latent_space/BiasAdd:0' shape=(?, 256) dtype=float32>
