# %%
import autoencoder.adversarial_cluster as aaec
import autoencoder.adversarial as aae
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
aae.train(1001, display=True, display_int=500, report_int=50,title="Adver_try3")
# Out:
# Using data from: /media/cjw/Data/cyto/mmCompensatedTifs/
# Saving checkpoints to: /media/cjw/Data/cyto/Checkpoints/2018-07-26-16-27-41_Adver_try3/checkpoint-2018-07-26-16-27-41/autoencoder-64x
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# ['Fish3_CCB.mm', 'Fish4_ICE.mm', 'Fish3_Untreated.mm', 'Fish6_Untreated.mm', 'Fish2_Untreated.mm', 'Fish1_Ice.mm', 'Fish5_Untreated.mm', 'Fish6_ICE.mm', 'Fish4_CCB.mm', 'Fish6_CCB.mm', 'Fish2_CCB.mm', 'Fish1_Untreated.mm', 'Fish4_Untreated.mm', 'Fish2_ICE.mm', 'Fish5_CCB.mm', 'Fish3_ICE.mm', 'Fish1_CCB.mm', 'Fish5_ICE.mm']
#    fid       file  id        mmfile  xc  yc
# 0    0  Fish3_CCB   0  Fish3_CCB.mm  32  32
# 1    1  Fish3_CCB   1  Fish3_CCB.mm  32  32
# 2    2  Fish3_CCB   2  Fish3_CCB.mm  32  32
# 3    3  Fish3_CCB   3  Fish3_CCB.mm  32  32
# 4    4  Fish3_CCB   4  Fish3_CCB.mm  32  32
# Encoder True
# Tensor("Placeholder:0", shape=(?, 32, 32, 4), dtype=float32) (?, 32, 32, 4)
# isize:  4 32
# dh0 (?, 32, 32, 4)
# [<tf.Variable 'encoder/filter_00/kernel:0' shape=(3, 3, 4, 128) dtype=float32_ref>, <tf.Variable 'encoder/filter_00/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'encoder/filter_01/kernel:0' shape=(3, 3, 128, 256) dtype=float32_ref>, <tf.Variable 'encoder/filter_01/bias:0' shape=(256,) dtype=float32_ref>, <tf.Variable 'encoder/filter_02/kernel:0' shape=(3, 3, 256, 512) dtype=float32_ref>, <tf.Variable 'encoder/filter_02/bias:0' shape=(512,) dtype=float32_ref>, <tf.Variable 'encoder/latent_space/kernel:0' shape=(8192, 64) dtype=float32_ref>, <tf.Variable 'encoder/latent_space/bias:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'decoder/dense/kernel:0' shape=(64, 8192) dtype=float32_ref>, <tf.Variable 'decoder/dense/bias:0' shape=(8192,) dtype=float32_ref>, <tf.Variable 'decoder/conv2d_transpose/kernel:0' shape=(3, 3, 256, 512) dtype=float32_ref>, <tf.Variable 'decoder/conv2d_transpose/bias:0' shape=(256,) dtype=float32_ref>, <tf.Variable 'decoder/conv2d_transpose_1/kernel:0' shape=(3, 3, 128, 256) dtype=float32_ref>, <tf.Variable 'decoder/conv2d_transpose_1/bias:0' shape=(128,) dtype=float32_ref>, <tf.Variable 'decoder/decoder_out/kernel:0' shape=(5, 5, 4, 128) dtype=float32_ref>, <tf.Variable 'decoder/decoder_out/bias:0' shape=(4,) dtype=float32_ref>]
# 0 1.6140866 0.5293869 367.90152
# 50 1.2110091 0.7563037 23.300728
# 100 1.1227422 0.8469994 19.115206
# 150 1.1029567 0.91517663 21.88376
# 200 1.0683451 1.0802116 28.4255
# 250 1.4213444 0.6806347 26.995804
# 300 5.832958 1.0153185 40.597702
# 350 2.072023 0.50194085 19.995167
# 400 2.8133554 0.50253 22.699896
# 450 1.3607868 0.69291604 16.970337
# 500 1.8067772 0.53817415 16.003979
# 550 1.3082196 0.7719576 14.100515
# 600 1.5899423 0.89124125 17.491074
# 650 1.3866751 0.6048965 13.27171
# 700 1.2547482 0.83194864 13.151096
# 750 1.2083272 0.889348 13.637607
# 800 2.0898013 0.6145311 14.417918
# 850 1.6362395 0.5657237 14.972353
# 900 1.1864712 0.74760455 12.169193
# 950 1.6110425 0.60063076 13.148054
# 1000 1.8215158 0.55501413 16.611673
# Done
