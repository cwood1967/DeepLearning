# %% [markdown]
# This is for using 4 channels, one brightfield and 3 fluorescent in the autoencoder.
#
# ### This is using compensated images
# - Data directory: '/media/cjw/Data/cyto/mmFromTifs3/'
# - Checkpoint directory;: "/media/cjw/Data/cyto/Checkpoints/2018-04-17-Chs-0-1-2-4_32_mmFromTifs3/checkpoint-2018-04-17-10-18-24/"
# - Checkpoint file: 'autoencoder-256x-13980.meta'

# %%
import sys

# %%
sys.executable
sys.path.append('/Users/cjw/Projects/cjw/cyto/DeepLearning')

# %%
'''
Import the modules that will be used
'''

import sys
import warnings
from distutils.version import LooseVersion
import os

import numpy as np
import tensorflow as tf
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
#import hdbscan

import holoviews as hv
from autoencoder import network
from autoencoder import utils


import umap
# %matplotlib inline
# %pwd
# Out:
# '/Users/cjw/Projects/cjw/cyto/DeepLearning/autoencoder/ZebraFish2'

# %%
tf.__version__
# Out:
# '1.11.0'

# %%
datadir =  '/Users/cjw/Data/cyto/zf_sorted/'
cp_dir = "/Users/cjw/Data/cyto/Checkpoints/2018-12-31-ZebraFish2_bf_ce/checkpoint-2018-12-31-20-19-21/"
aemeta = 'autoencoder-128x-30719.meta'
if os.path.exists(cp_dir + aemeta):
    print("OK")
# Out:
# OK

# %%
'''
Define the neural network that was used and define hyper-parameters.
These are needed to infer from the saved network checkpoint
'''

tf.reset_default_graph()
                  
print(cp_dir)

if os.path.exists(cp_dir):
    print("OK, exists")
else:
    print("Oh no")
#checkpoint-2018-03-02-16-31-42/'
p_width = 32
p_height = 32
p_nchannels = 1
p_channels = [0]
p_nepochs = 40
p_batchsize = 128
p_learning_rate = 0.0002  #.00005
p_restore = False
p_latent_size = 128
p_droprate = 0.75
p_stdev = .04

enc_sizes = [(128, 3), (256, 3), (512, 3)] 
#enc_sizes = [(128, 3), (256, 3), (512,3), (1024,3)] #, (64, 3), (128,3)] #, (32, 3), (64, 3)]
dec_sizes = list(reversed(enc_sizes))
# enc_sizes = [(64, 5), (128, 3), (256,3), (512,3)]
# dec_sizes = list(reversed(enc_sizes))

# images = tf.placeholder(tf.float32, (None, p_height, p_width, p_nchannels))
# z = tf.placeholder(tf.float32, (None, p_latent_size))

# enc = network.encoder(images, p_latent_size, droprate=p_droprate, is_train=False,
#                       nfilters=enc_sizes)
# sdd = network.decoder(enc, nchannels=p_nchannels, width=p_width, droprate=p_droprate,
#                       is_train=False, nfilters=dec_sizes)

# loss, _, _ = network.ae_loss(images, sdd)

# opt = network.model_opt(loss, p_learning_rate)

# saver = tf.train.Saver()

sess = tf.Session()
sess.run(tf.global_variables_initializer())
saver = tf.train.import_meta_graph(cp_dir + aemeta)
saver.restore(sess, cp_dir + aemeta.split('.')[0])
# Out:
# /Users/cjw/Data/cyto/Checkpoints/2018-12-31-ZebraFish2_bf_ce/checkpoint-2018-12-31-20-19-21/
# OK, exists
# INFO:tensorflow:Restoring parameters from /Users/cjw/Data/cyto/Checkpoints/2018-12-31-ZebraFish2_bf_ce/checkpoint-2018-12-31-20-19-21/autoencoder-128x-30719

# %%
g = tf.get_default_graph()
ops = g.get_operations()
for op in ops:
    try:
        print(op.name, op.outputs, len(op.outputs))
    except:
        print(op.name, "no output")
    print('------')
# Out:
# init [] 0
# ------
# Placeholder [<tf.Tensor 'Placeholder:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# Placeholder_1 [<tf.Tensor 'Placeholder_1:0' shape=(?, 128) dtype=float32>] 1
# ------
# filter_00/kernel/Initializer/truncated_normal/shape [<tf.Tensor 'filter_00/kernel/Initializer/truncated_normal/shape:0' shape=(4,) dtype=int32>] 1
# ------
# filter_00/kernel/Initializer/truncated_normal/mean [<tf.Tensor 'filter_00/kernel/Initializer/truncated_normal/mean:0' shape=() dtype=float32>] 1
# ------
# filter_00/kernel/Initializer/truncated_normal/stddev [<tf.Tensor 'filter_00/kernel/Initializer/truncated_normal/stddev:0' shape=() dtype=float32>] 1
# ------
# filter_00/kernel/Initializer/truncated_normal/TruncatedNormal [<tf.Tensor 'filter_00/kernel/Initializer/truncated_normal/TruncatedNormal:0' shape=(3, 3, 1, 128) dtype=float32>] 1
# ------
# filter_00/kernel/Initializer/truncated_normal/mul [<tf.Tensor 'filter_00/kernel/Initializer/truncated_normal/mul:0' shape=(3, 3, 1, 128) dtype=float32>] 1
# ------
# filter_00/kernel/Initializer/truncated_normal [<tf.Tensor 'filter_00/kernel/Initializer/truncated_normal:0' shape=(3, 3, 1, 128) dtype=float32>] 1
# ------
# filter_00/kernel [<tf.Tensor 'filter_00/kernel:0' shape=(3, 3, 1, 128) dtype=float32_ref>] 1
# ------
# filter_00/kernel/Assign [<tf.Tensor 'filter_00/kernel/Assign:0' shape=(3, 3, 1, 128) dtype=float32_ref>] 1
# ------
# filter_00/kernel/read [<tf.Tensor 'filter_00/kernel/read:0' shape=(3, 3, 1, 128) dtype=float32>] 1
# ------
# filter_00/bias/Initializer/zeros [<tf.Tensor 'filter_00/bias/Initializer/zeros:0' shape=(128,) dtype=float32>] 1
# ------
# filter_00/bias [<tf.Tensor 'filter_00/bias:0' shape=(128,) dtype=float32_ref>] 1
# ------
# filter_00/bias/Assign [<tf.Tensor 'filter_00/bias/Assign:0' shape=(128,) dtype=float32_ref>] 1
# ------
# filter_00/bias/read [<tf.Tensor 'filter_00/bias/read:0' shape=(128,) dtype=float32>] 1
# ------
# filter_00/dilation_rate [<tf.Tensor 'filter_00/dilation_rate:0' shape=(2,) dtype=int32>] 1
# ------
# filter_00/Conv2D [<tf.Tensor 'filter_00/Conv2D:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# filter_00/BiasAdd [<tf.Tensor 'filter_00/BiasAdd:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# mul/y [<tf.Tensor 'mul/y:0' shape=() dtype=float32>] 1
# ------
# mul [<tf.Tensor 'mul:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# Maximum [<tf.Tensor 'Maximum:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# dropout/keep_prob [<tf.Tensor 'dropout/keep_prob:0' shape=() dtype=float32>] 1
# ------
# dropout/Shape [<tf.Tensor 'dropout/Shape:0' shape=(4,) dtype=int32>] 1
# ------
# dropout/random_uniform/min [<tf.Tensor 'dropout/random_uniform/min:0' shape=() dtype=float32>] 1
# ------
# dropout/random_uniform/max [<tf.Tensor 'dropout/random_uniform/max:0' shape=() dtype=float32>] 1
# ------
# dropout/random_uniform/RandomUniform [<tf.Tensor 'dropout/random_uniform/RandomUniform:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# dropout/random_uniform/sub [<tf.Tensor 'dropout/random_uniform/sub:0' shape=() dtype=float32>] 1
# ------
# dropout/random_uniform/mul [<tf.Tensor 'dropout/random_uniform/mul:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# dropout/random_uniform [<tf.Tensor 'dropout/random_uniform:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# dropout/add [<tf.Tensor 'dropout/add:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# dropout/Floor [<tf.Tensor 'dropout/Floor:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# dropout/div [<tf.Tensor 'dropout/div:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# dropout/mul [<tf.Tensor 'dropout/mul:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# filter_01/kernel/Initializer/truncated_normal/shape [<tf.Tensor 'filter_01/kernel/Initializer/truncated_normal/shape:0' shape=(4,) dtype=int32>] 1
# ------
# filter_01/kernel/Initializer/truncated_normal/mean [<tf.Tensor 'filter_01/kernel/Initializer/truncated_normal/mean:0' shape=() dtype=float32>] 1
# ------
# filter_01/kernel/Initializer/truncated_normal/stddev [<tf.Tensor 'filter_01/kernel/Initializer/truncated_normal/stddev:0' shape=() dtype=float32>] 1
# ------
# filter_01/kernel/Initializer/truncated_normal/TruncatedNormal [<tf.Tensor 'filter_01/kernel/Initializer/truncated_normal/TruncatedNormal:0' shape=(3, 3, 128, 256) dtype=float32>] 1
# ------
# filter_01/kernel/Initializer/truncated_normal/mul [<tf.Tensor 'filter_01/kernel/Initializer/truncated_normal/mul:0' shape=(3, 3, 128, 256) dtype=float32>] 1
# ------
# filter_01/kernel/Initializer/truncated_normal [<tf.Tensor 'filter_01/kernel/Initializer/truncated_normal:0' shape=(3, 3, 128, 256) dtype=float32>] 1
# ------
# filter_01/kernel [<tf.Tensor 'filter_01/kernel:0' shape=(3, 3, 128, 256) dtype=float32_ref>] 1
# ------
# filter_01/kernel/Assign [<tf.Tensor 'filter_01/kernel/Assign:0' shape=(3, 3, 128, 256) dtype=float32_ref>] 1
# ------
# filter_01/kernel/read [<tf.Tensor 'filter_01/kernel/read:0' shape=(3, 3, 128, 256) dtype=float32>] 1
# ------
# filter_01/bias/Initializer/zeros [<tf.Tensor 'filter_01/bias/Initializer/zeros:0' shape=(256,) dtype=float32>] 1
# ------
# filter_01/bias [<tf.Tensor 'filter_01/bias:0' shape=(256,) dtype=float32_ref>] 1
# ------
# filter_01/bias/Assign [<tf.Tensor 'filter_01/bias/Assign:0' shape=(256,) dtype=float32_ref>] 1
# ------
# filter_01/bias/read [<tf.Tensor 'filter_01/bias/read:0' shape=(256,) dtype=float32>] 1
# ------
# filter_01/dilation_rate [<tf.Tensor 'filter_01/dilation_rate:0' shape=(2,) dtype=int32>] 1
# ------
# filter_01/Conv2D [<tf.Tensor 'filter_01/Conv2D:0' shape=(?, 8, 8, 256) dtype=float32>] 1
# ------
# filter_01/BiasAdd [<tf.Tensor 'filter_01/BiasAdd:0' shape=(?, 8, 8, 256) dtype=float32>] 1
# ------
# mul_1/y [<tf.Tensor 'mul_1/y:0' shape=() dtype=float32>] 1
# ------
# mul_1 [<tf.Tensor 'mul_1:0' shape=(?, 8, 8, 256) dtype=float32>] 1
# ------
# Maximum_1 [<tf.Tensor 'Maximum_1:0' shape=(?, 8, 8, 256) dtype=float32>] 1
# ------
# dropout_1/keep_prob [<tf.Tensor 'dropout_1/keep_prob:0' shape=() dtype=float32>] 1
# ------
# dropout_1/Shape [<tf.Tensor 'dropout_1/Shape:0' shape=(4,) dtype=int32>] 1
# ------
# dropout_1/random_uniform/min [<tf.Tensor 'dropout_1/random_uniform/min:0' shape=() dtype=float32>] 1
# ------
# dropout_1/random_uniform/max [<tf.Tensor 'dropout_1/random_uniform/max:0' shape=() dtype=float32>] 1
# ------
# dropout_1/random_uniform/RandomUniform [<tf.Tensor 'dropout_1/random_uniform/RandomUniform:0' shape=(?, 8, 8, 256) dtype=float32>] 1
# ------
# dropout_1/random_uniform/sub [<tf.Tensor 'dropout_1/random_uniform/sub:0' shape=() dtype=float32>] 1
# ------
# dropout_1/random_uniform/mul [<tf.Tensor 'dropout_1/random_uniform/mul:0' shape=(?, 8, 8, 256) dtype=float32>] 1
# ------
# dropout_1/random_uniform [<tf.Tensor 'dropout_1/random_uniform:0' shape=(?, 8, 8, 256) dtype=float32>] 1
# ------
# dropout_1/add [<tf.Tensor 'dropout_1/add:0' shape=(?, 8, 8, 256) dtype=float32>] 1
# ------
# dropout_1/Floor [<tf.Tensor 'dropout_1/Floor:0' shape=(?, 8, 8, 256) dtype=float32>] 1
# ------
# dropout_1/div [<tf.Tensor 'dropout_1/div:0' shape=(?, 8, 8, 256) dtype=float32>] 1
# ------
# dropout_1/mul [<tf.Tensor 'dropout_1/mul:0' shape=(?, 8, 8, 256) dtype=float32>] 1
# ------
# filter_02/kernel/Initializer/truncated_normal/shape [<tf.Tensor 'filter_02/kernel/Initializer/truncated_normal/shape:0' shape=(4,) dtype=int32>] 1
# ------
# filter_02/kernel/Initializer/truncated_normal/mean [<tf.Tensor 'filter_02/kernel/Initializer/truncated_normal/mean:0' shape=() dtype=float32>] 1
# ------
# filter_02/kernel/Initializer/truncated_normal/stddev [<tf.Tensor 'filter_02/kernel/Initializer/truncated_normal/stddev:0' shape=() dtype=float32>] 1
# ------
# filter_02/kernel/Initializer/truncated_normal/TruncatedNormal [<tf.Tensor 'filter_02/kernel/Initializer/truncated_normal/TruncatedNormal:0' shape=(3, 3, 256, 512) dtype=float32>] 1
# ------
# filter_02/kernel/Initializer/truncated_normal/mul [<tf.Tensor 'filter_02/kernel/Initializer/truncated_normal/mul:0' shape=(3, 3, 256, 512) dtype=float32>] 1
# ------
# filter_02/kernel/Initializer/truncated_normal [<tf.Tensor 'filter_02/kernel/Initializer/truncated_normal:0' shape=(3, 3, 256, 512) dtype=float32>] 1
# ------
# filter_02/kernel [<tf.Tensor 'filter_02/kernel:0' shape=(3, 3, 256, 512) dtype=float32_ref>] 1
# ------
# filter_02/kernel/Assign [<tf.Tensor 'filter_02/kernel/Assign:0' shape=(3, 3, 256, 512) dtype=float32_ref>] 1
# ------
# filter_02/kernel/read [<tf.Tensor 'filter_02/kernel/read:0' shape=(3, 3, 256, 512) dtype=float32>] 1
# ------
# filter_02/bias/Initializer/zeros [<tf.Tensor 'filter_02/bias/Initializer/zeros:0' shape=(512,) dtype=float32>] 1
# ------
# filter_02/bias [<tf.Tensor 'filter_02/bias:0' shape=(512,) dtype=float32_ref>] 1
# ------
# filter_02/bias/Assign [<tf.Tensor 'filter_02/bias/Assign:0' shape=(512,) dtype=float32_ref>] 1
# ------
# filter_02/bias/read [<tf.Tensor 'filter_02/bias/read:0' shape=(512,) dtype=float32>] 1
# ------
# filter_02/dilation_rate [<tf.Tensor 'filter_02/dilation_rate:0' shape=(2,) dtype=int32>] 1
# ------
# filter_02/Conv2D [<tf.Tensor 'filter_02/Conv2D:0' shape=(?, 4, 4, 512) dtype=float32>] 1
# ------
# filter_02/BiasAdd [<tf.Tensor 'filter_02/BiasAdd:0' shape=(?, 4, 4, 512) dtype=float32>] 1
# ------
# mul_2/y [<tf.Tensor 'mul_2/y:0' shape=() dtype=float32>] 1
# ------
# mul_2 [<tf.Tensor 'mul_2:0' shape=(?, 4, 4, 512) dtype=float32>] 1
# ------
# Maximum_2 [<tf.Tensor 'Maximum_2:0' shape=(?, 4, 4, 512) dtype=float32>] 1
# ------
# dropout_2/keep_prob [<tf.Tensor 'dropout_2/keep_prob:0' shape=() dtype=float32>] 1
# ------
# dropout_2/Shape [<tf.Tensor 'dropout_2/Shape:0' shape=(4,) dtype=int32>] 1
# ------
# dropout_2/random_uniform/min [<tf.Tensor 'dropout_2/random_uniform/min:0' shape=() dtype=float32>] 1
# ------
# dropout_2/random_uniform/max [<tf.Tensor 'dropout_2/random_uniform/max:0' shape=() dtype=float32>] 1
# ------
# dropout_2/random_uniform/RandomUniform [<tf.Tensor 'dropout_2/random_uniform/RandomUniform:0' shape=(?, 4, 4, 512) dtype=float32>] 1
# ------
# dropout_2/random_uniform/sub [<tf.Tensor 'dropout_2/random_uniform/sub:0' shape=() dtype=float32>] 1
# ------
# dropout_2/random_uniform/mul [<tf.Tensor 'dropout_2/random_uniform/mul:0' shape=(?, 4, 4, 512) dtype=float32>] 1
# ------
# dropout_2/random_uniform [<tf.Tensor 'dropout_2/random_uniform:0' shape=(?, 4, 4, 512) dtype=float32>] 1
# ------
# dropout_2/add [<tf.Tensor 'dropout_2/add:0' shape=(?, 4, 4, 512) dtype=float32>] 1
# ------
# dropout_2/Floor [<tf.Tensor 'dropout_2/Floor:0' shape=(?, 4, 4, 512) dtype=float32>] 1
# ------
# dropout_2/div [<tf.Tensor 'dropout_2/div:0' shape=(?, 4, 4, 512) dtype=float32>] 1
# ------
# dropout_2/mul [<tf.Tensor 'dropout_2/mul:0' shape=(?, 4, 4, 512) dtype=float32>] 1
# ------
# Flatten/flatten/Shape [<tf.Tensor 'Flatten/flatten/Shape:0' shape=(4,) dtype=int32>] 1
# ------
# Flatten/flatten/strided_slice/stack [<tf.Tensor 'Flatten/flatten/strided_slice/stack:0' shape=(1,) dtype=int32>] 1
# ------
# Flatten/flatten/strided_slice/stack_1 [<tf.Tensor 'Flatten/flatten/strided_slice/stack_1:0' shape=(1,) dtype=int32>] 1
# ------
# Flatten/flatten/strided_slice/stack_2 [<tf.Tensor 'Flatten/flatten/strided_slice/stack_2:0' shape=(1,) dtype=int32>] 1
# ------
# Flatten/flatten/strided_slice [<tf.Tensor 'Flatten/flatten/strided_slice:0' shape=() dtype=int32>] 1
# ------
# Flatten/flatten/Reshape/shape/1 [<tf.Tensor 'Flatten/flatten/Reshape/shape/1:0' shape=() dtype=int32>] 1
# ------
# Flatten/flatten/Reshape/shape [<tf.Tensor 'Flatten/flatten/Reshape/shape:0' shape=(2,) dtype=int32>] 1
# ------
# Flatten/flatten/Reshape [<tf.Tensor 'Flatten/flatten/Reshape:0' shape=(?, 8192) dtype=float32>] 1
# ------
# latent_space/kernel/Initializer/truncated_normal/shape [<tf.Tensor 'latent_space/kernel/Initializer/truncated_normal/shape:0' shape=(2,) dtype=int32>] 1
# ------
# latent_space/kernel/Initializer/truncated_normal/mean [<tf.Tensor 'latent_space/kernel/Initializer/truncated_normal/mean:0' shape=() dtype=float32>] 1
# ------
# latent_space/kernel/Initializer/truncated_normal/stddev [<tf.Tensor 'latent_space/kernel/Initializer/truncated_normal/stddev:0' shape=() dtype=float32>] 1
# ------
# latent_space/kernel/Initializer/truncated_normal/TruncatedNormal [<tf.Tensor 'latent_space/kernel/Initializer/truncated_normal/TruncatedNormal:0' shape=(8192, 128) dtype=float32>] 1
# ------
# latent_space/kernel/Initializer/truncated_normal/mul [<tf.Tensor 'latent_space/kernel/Initializer/truncated_normal/mul:0' shape=(8192, 128) dtype=float32>] 1
# ------
# latent_space/kernel/Initializer/truncated_normal [<tf.Tensor 'latent_space/kernel/Initializer/truncated_normal:0' shape=(8192, 128) dtype=float32>] 1
# ------
# latent_space/kernel [<tf.Tensor 'latent_space/kernel:0' shape=(8192, 128) dtype=float32_ref>] 1
# ------
# latent_space/kernel/Assign [<tf.Tensor 'latent_space/kernel/Assign:0' shape=(8192, 128) dtype=float32_ref>] 1
# ------
# latent_space/kernel/read [<tf.Tensor 'latent_space/kernel/read:0' shape=(8192, 128) dtype=float32>] 1
# ------
# latent_space/bias/Initializer/zeros [<tf.Tensor 'latent_space/bias/Initializer/zeros:0' shape=(128,) dtype=float32>] 1
# ------
# latent_space/bias [<tf.Tensor 'latent_space/bias:0' shape=(128,) dtype=float32_ref>] 1
# ------
# latent_space/bias/Assign [<tf.Tensor 'latent_space/bias/Assign:0' shape=(128,) dtype=float32_ref>] 1
# ------
# latent_space/bias/read [<tf.Tensor 'latent_space/bias/read:0' shape=(128,) dtype=float32>] 1
# ------
# latent_space/MatMul [<tf.Tensor 'latent_space/MatMul:0' shape=(?, 128) dtype=float32>] 1
# ------
# latent_space/BiasAdd [<tf.Tensor 'latent_space/BiasAdd:0' shape=(?, 128) dtype=float32>] 1
# ------
# dense/kernel/Initializer/truncated_normal/shape [<tf.Tensor 'dense/kernel/Initializer/truncated_normal/shape:0' shape=(2,) dtype=int32>] 1
# ------
# dense/kernel/Initializer/truncated_normal/mean [<tf.Tensor 'dense/kernel/Initializer/truncated_normal/mean:0' shape=() dtype=float32>] 1
# ------
# dense/kernel/Initializer/truncated_normal/stddev [<tf.Tensor 'dense/kernel/Initializer/truncated_normal/stddev:0' shape=() dtype=float32>] 1
# ------
# dense/kernel/Initializer/truncated_normal/TruncatedNormal [<tf.Tensor 'dense/kernel/Initializer/truncated_normal/TruncatedNormal:0' shape=(128, 8192) dtype=float32>] 1
# ------
# dense/kernel/Initializer/truncated_normal/mul [<tf.Tensor 'dense/kernel/Initializer/truncated_normal/mul:0' shape=(128, 8192) dtype=float32>] 1
# ------
# dense/kernel/Initializer/truncated_normal [<tf.Tensor 'dense/kernel/Initializer/truncated_normal:0' shape=(128, 8192) dtype=float32>] 1
# ------
# dense/kernel [<tf.Tensor 'dense/kernel:0' shape=(128, 8192) dtype=float32_ref>] 1
# ------
# dense/kernel/Assign [<tf.Tensor 'dense/kernel/Assign:0' shape=(128, 8192) dtype=float32_ref>] 1
# ------
# dense/kernel/read [<tf.Tensor 'dense/kernel/read:0' shape=(128, 8192) dtype=float32>] 1
# ------
# dense/bias/Initializer/zeros/shape_as_tensor [<tf.Tensor 'dense/bias/Initializer/zeros/shape_as_tensor:0' shape=(1,) dtype=int32>] 1
# ------
# dense/bias/Initializer/zeros/Const [<tf.Tensor 'dense/bias/Initializer/zeros/Const:0' shape=() dtype=float32>] 1
# ------
# dense/bias/Initializer/zeros [<tf.Tensor 'dense/bias/Initializer/zeros:0' shape=(8192,) dtype=float32>] 1
# ------
# dense/bias [<tf.Tensor 'dense/bias:0' shape=(8192,) dtype=float32_ref>] 1
# ------
# dense/bias/Assign [<tf.Tensor 'dense/bias/Assign:0' shape=(8192,) dtype=float32_ref>] 1
# ------
# dense/bias/read [<tf.Tensor 'dense/bias/read:0' shape=(8192,) dtype=float32>] 1
# ------
# dense/MatMul [<tf.Tensor 'dense/MatMul:0' shape=(?, 8192) dtype=float32>] 1
# ------
# dense/BiasAdd [<tf.Tensor 'dense/BiasAdd:0' shape=(?, 8192) dtype=float32>] 1
# ------
# mul_3/y [<tf.Tensor 'mul_3/y:0' shape=() dtype=float32>] 1
# ------
# mul_3 [<tf.Tensor 'mul_3:0' shape=(?, 8192) dtype=float32>] 1
# ------
# Maximum_3 [<tf.Tensor 'Maximum_3:0' shape=(?, 8192) dtype=float32>] 1
# ------
# dropout_3/keep_prob [<tf.Tensor 'dropout_3/keep_prob:0' shape=() dtype=float32>] 1
# ------
# dropout_3/Shape [<tf.Tensor 'dropout_3/Shape:0' shape=(2,) dtype=int32>] 1
# ------
# dropout_3/random_uniform/min [<tf.Tensor 'dropout_3/random_uniform/min:0' shape=() dtype=float32>] 1
# ------
# dropout_3/random_uniform/max [<tf.Tensor 'dropout_3/random_uniform/max:0' shape=() dtype=float32>] 1
# ------
# dropout_3/random_uniform/RandomUniform [<tf.Tensor 'dropout_3/random_uniform/RandomUniform:0' shape=(?, 8192) dtype=float32>] 1
# ------
# dropout_3/random_uniform/sub [<tf.Tensor 'dropout_3/random_uniform/sub:0' shape=() dtype=float32>] 1
# ------
# dropout_3/random_uniform/mul [<tf.Tensor 'dropout_3/random_uniform/mul:0' shape=(?, 8192) dtype=float32>] 1
# ------
# dropout_3/random_uniform [<tf.Tensor 'dropout_3/random_uniform:0' shape=(?, 8192) dtype=float32>] 1
# ------
# dropout_3/add [<tf.Tensor 'dropout_3/add:0' shape=(?, 8192) dtype=float32>] 1
# ------
# dropout_3/Floor [<tf.Tensor 'dropout_3/Floor:0' shape=(?, 8192) dtype=float32>] 1
# ------
# dropout_3/div [<tf.Tensor 'dropout_3/div:0' shape=(?, 8192) dtype=float32>] 1
# ------
# dropout_3/mul [<tf.Tensor 'dropout_3/mul:0' shape=(?, 8192) dtype=float32>] 1
# ------
# Reshape/shape [<tf.Tensor 'Reshape/shape:0' shape=(4,) dtype=int32>] 1
# ------
# Reshape [<tf.Tensor 'Reshape:0' shape=(?, 4, 4, 512) dtype=float32>] 1
# ------
# conv2d_transpose/kernel/Initializer/truncated_normal/shape [<tf.Tensor 'conv2d_transpose/kernel/Initializer/truncated_normal/shape:0' shape=(4,) dtype=int32>] 1
# ------
# conv2d_transpose/kernel/Initializer/truncated_normal/mean [<tf.Tensor 'conv2d_transpose/kernel/Initializer/truncated_normal/mean:0' shape=() dtype=float32>] 1
# ------
# conv2d_transpose/kernel/Initializer/truncated_normal/stddev [<tf.Tensor 'conv2d_transpose/kernel/Initializer/truncated_normal/stddev:0' shape=() dtype=float32>] 1
# ------
# conv2d_transpose/kernel/Initializer/truncated_normal/TruncatedNormal [<tf.Tensor 'conv2d_transpose/kernel/Initializer/truncated_normal/TruncatedNormal:0' shape=(3, 3, 256, 512) dtype=float32>] 1
# ------
# conv2d_transpose/kernel/Initializer/truncated_normal/mul [<tf.Tensor 'conv2d_transpose/kernel/Initializer/truncated_normal/mul:0' shape=(3, 3, 256, 512) dtype=float32>] 1
# ------
# conv2d_transpose/kernel/Initializer/truncated_normal [<tf.Tensor 'conv2d_transpose/kernel/Initializer/truncated_normal:0' shape=(3, 3, 256, 512) dtype=float32>] 1
# ------
# conv2d_transpose/kernel [<tf.Tensor 'conv2d_transpose/kernel:0' shape=(3, 3, 256, 512) dtype=float32_ref>] 1
# ------
# conv2d_transpose/kernel/Assign [<tf.Tensor 'conv2d_transpose/kernel/Assign:0' shape=(3, 3, 256, 512) dtype=float32_ref>] 1
# ------
# conv2d_transpose/kernel/read [<tf.Tensor 'conv2d_transpose/kernel/read:0' shape=(3, 3, 256, 512) dtype=float32>] 1
# ------
# conv2d_transpose/bias/Initializer/zeros [<tf.Tensor 'conv2d_transpose/bias/Initializer/zeros:0' shape=(256,) dtype=float32>] 1
# ------
# conv2d_transpose/bias [<tf.Tensor 'conv2d_transpose/bias:0' shape=(256,) dtype=float32_ref>] 1
# ------
# conv2d_transpose/bias/Assign [<tf.Tensor 'conv2d_transpose/bias/Assign:0' shape=(256,) dtype=float32_ref>] 1
# ------
# conv2d_transpose/bias/read [<tf.Tensor 'conv2d_transpose/bias/read:0' shape=(256,) dtype=float32>] 1
# ------
# conv2d_transpose/Shape [<tf.Tensor 'conv2d_transpose/Shape:0' shape=(4,) dtype=int32>] 1
# ------
# conv2d_transpose/strided_slice/stack [<tf.Tensor 'conv2d_transpose/strided_slice/stack:0' shape=(1,) dtype=int32>] 1
# ------
# conv2d_transpose/strided_slice/stack_1 [<tf.Tensor 'conv2d_transpose/strided_slice/stack_1:0' shape=(1,) dtype=int32>] 1
# ------
# conv2d_transpose/strided_slice/stack_2 [<tf.Tensor 'conv2d_transpose/strided_slice/stack_2:0' shape=(1,) dtype=int32>] 1
# ------
# conv2d_transpose/strided_slice [<tf.Tensor 'conv2d_transpose/strided_slice:0' shape=() dtype=int32>] 1
# ------
# conv2d_transpose/strided_slice_1/stack [<tf.Tensor 'conv2d_transpose/strided_slice_1/stack:0' shape=(1,) dtype=int32>] 1
# ------
# conv2d_transpose/strided_slice_1/stack_1 [<tf.Tensor 'conv2d_transpose/strided_slice_1/stack_1:0' shape=(1,) dtype=int32>] 1
# ------
# conv2d_transpose/strided_slice_1/stack_2 [<tf.Tensor 'conv2d_transpose/strided_slice_1/stack_2:0' shape=(1,) dtype=int32>] 1
# ------
# conv2d_transpose/strided_slice_1 [<tf.Tensor 'conv2d_transpose/strided_slice_1:0' shape=() dtype=int32>] 1
# ------
# conv2d_transpose/strided_slice_2/stack [<tf.Tensor 'conv2d_transpose/strided_slice_2/stack:0' shape=(1,) dtype=int32>] 1
# ------
# conv2d_transpose/strided_slice_2/stack_1 [<tf.Tensor 'conv2d_transpose/strided_slice_2/stack_1:0' shape=(1,) dtype=int32>] 1
# ------
# conv2d_transpose/strided_slice_2/stack_2 [<tf.Tensor 'conv2d_transpose/strided_slice_2/stack_2:0' shape=(1,) dtype=int32>] 1
# ------
# conv2d_transpose/strided_slice_2 [<tf.Tensor 'conv2d_transpose/strided_slice_2:0' shape=() dtype=int32>] 1
# ------
# conv2d_transpose/mul/y [<tf.Tensor 'conv2d_transpose/mul/y:0' shape=() dtype=int32>] 1
# ------
# conv2d_transpose/mul [<tf.Tensor 'conv2d_transpose/mul:0' shape=() dtype=int32>] 1
# ------
# conv2d_transpose/mul_1/y [<tf.Tensor 'conv2d_transpose/mul_1/y:0' shape=() dtype=int32>] 1
# ------
# conv2d_transpose/mul_1 [<tf.Tensor 'conv2d_transpose/mul_1:0' shape=() dtype=int32>] 1
# ------
# conv2d_transpose/stack/3 [<tf.Tensor 'conv2d_transpose/stack/3:0' shape=() dtype=int32>] 1
# ------
# conv2d_transpose/stack [<tf.Tensor 'conv2d_transpose/stack:0' shape=(4,) dtype=int32>] 1
# ------
# conv2d_transpose/conv2d_transpose [<tf.Tensor 'conv2d_transpose/conv2d_transpose:0' shape=(?, 8, 8, 256) dtype=float32>] 1
# ------
# conv2d_transpose/BiasAdd [<tf.Tensor 'conv2d_transpose/BiasAdd:0' shape=(?, 8, 8, 256) dtype=float32>] 1
# ------
# mul_4/y [<tf.Tensor 'mul_4/y:0' shape=() dtype=float32>] 1
# ------
# mul_4 [<tf.Tensor 'mul_4:0' shape=(?, 8, 8, 256) dtype=float32>] 1
# ------
# Maximum_4 [<tf.Tensor 'Maximum_4:0' shape=(?, 8, 8, 256) dtype=float32>] 1
# ------
# dropout_4/keep_prob [<tf.Tensor 'dropout_4/keep_prob:0' shape=() dtype=float32>] 1
# ------
# dropout_4/Shape [<tf.Tensor 'dropout_4/Shape:0' shape=(4,) dtype=int32>] 1
# ------
# dropout_4/random_uniform/min [<tf.Tensor 'dropout_4/random_uniform/min:0' shape=() dtype=float32>] 1
# ------
# dropout_4/random_uniform/max [<tf.Tensor 'dropout_4/random_uniform/max:0' shape=() dtype=float32>] 1
# ------
# dropout_4/random_uniform/RandomUniform [<tf.Tensor 'dropout_4/random_uniform/RandomUniform:0' shape=(?, 8, 8, 256) dtype=float32>] 1
# ------
# dropout_4/random_uniform/sub [<tf.Tensor 'dropout_4/random_uniform/sub:0' shape=() dtype=float32>] 1
# ------
# dropout_4/random_uniform/mul [<tf.Tensor 'dropout_4/random_uniform/mul:0' shape=(?, 8, 8, 256) dtype=float32>] 1
# ------
# dropout_4/random_uniform [<tf.Tensor 'dropout_4/random_uniform:0' shape=(?, 8, 8, 256) dtype=float32>] 1
# ------
# dropout_4/add [<tf.Tensor 'dropout_4/add:0' shape=(?, 8, 8, 256) dtype=float32>] 1
# ------
# dropout_4/Floor [<tf.Tensor 'dropout_4/Floor:0' shape=(?, 8, 8, 256) dtype=float32>] 1
# ------
# dropout_4/div [<tf.Tensor 'dropout_4/div:0' shape=(?, 8, 8, 256) dtype=float32>] 1
# ------
# dropout_4/mul [<tf.Tensor 'dropout_4/mul:0' shape=(?, 8, 8, 256) dtype=float32>] 1
# ------
# conv2d_transpose_1/kernel/Initializer/truncated_normal/shape [<tf.Tensor 'conv2d_transpose_1/kernel/Initializer/truncated_normal/shape:0' shape=(4,) dtype=int32>] 1
# ------
# conv2d_transpose_1/kernel/Initializer/truncated_normal/mean [<tf.Tensor 'conv2d_transpose_1/kernel/Initializer/truncated_normal/mean:0' shape=() dtype=float32>] 1
# ------
# conv2d_transpose_1/kernel/Initializer/truncated_normal/stddev [<tf.Tensor 'conv2d_transpose_1/kernel/Initializer/truncated_normal/stddev:0' shape=() dtype=float32>] 1
# ------
# conv2d_transpose_1/kernel/Initializer/truncated_normal/TruncatedNormal [<tf.Tensor 'conv2d_transpose_1/kernel/Initializer/truncated_normal/TruncatedNormal:0' shape=(3, 3, 128, 256) dtype=float32>] 1
# ------
# conv2d_transpose_1/kernel/Initializer/truncated_normal/mul [<tf.Tensor 'conv2d_transpose_1/kernel/Initializer/truncated_normal/mul:0' shape=(3, 3, 128, 256) dtype=float32>] 1
# ------
# conv2d_transpose_1/kernel/Initializer/truncated_normal [<tf.Tensor 'conv2d_transpose_1/kernel/Initializer/truncated_normal:0' shape=(3, 3, 128, 256) dtype=float32>] 1
# ------
# conv2d_transpose_1/kernel [<tf.Tensor 'conv2d_transpose_1/kernel:0' shape=(3, 3, 128, 256) dtype=float32_ref>] 1
# ------
# conv2d_transpose_1/kernel/Assign [<tf.Tensor 'conv2d_transpose_1/kernel/Assign:0' shape=(3, 3, 128, 256) dtype=float32_ref>] 1
# ------
# conv2d_transpose_1/kernel/read [<tf.Tensor 'conv2d_transpose_1/kernel/read:0' shape=(3, 3, 128, 256) dtype=float32>] 1
# ------
# conv2d_transpose_1/bias/Initializer/zeros [<tf.Tensor 'conv2d_transpose_1/bias/Initializer/zeros:0' shape=(128,) dtype=float32>] 1
# ------
# conv2d_transpose_1/bias [<tf.Tensor 'conv2d_transpose_1/bias:0' shape=(128,) dtype=float32_ref>] 1
# ------
# conv2d_transpose_1/bias/Assign [<tf.Tensor 'conv2d_transpose_1/bias/Assign:0' shape=(128,) dtype=float32_ref>] 1
# ------
# conv2d_transpose_1/bias/read [<tf.Tensor 'conv2d_transpose_1/bias/read:0' shape=(128,) dtype=float32>] 1
# ------
# conv2d_transpose_1/Shape [<tf.Tensor 'conv2d_transpose_1/Shape:0' shape=(4,) dtype=int32>] 1
# ------
# conv2d_transpose_1/strided_slice/stack [<tf.Tensor 'conv2d_transpose_1/strided_slice/stack:0' shape=(1,) dtype=int32>] 1
# ------
# conv2d_transpose_1/strided_slice/stack_1 [<tf.Tensor 'conv2d_transpose_1/strided_slice/stack_1:0' shape=(1,) dtype=int32>] 1
# ------
# conv2d_transpose_1/strided_slice/stack_2 [<tf.Tensor 'conv2d_transpose_1/strided_slice/stack_2:0' shape=(1,) dtype=int32>] 1
# ------
# conv2d_transpose_1/strided_slice [<tf.Tensor 'conv2d_transpose_1/strided_slice:0' shape=() dtype=int32>] 1
# ------
# conv2d_transpose_1/strided_slice_1/stack [<tf.Tensor 'conv2d_transpose_1/strided_slice_1/stack:0' shape=(1,) dtype=int32>] 1
# ------
# conv2d_transpose_1/strided_slice_1/stack_1 [<tf.Tensor 'conv2d_transpose_1/strided_slice_1/stack_1:0' shape=(1,) dtype=int32>] 1
# ------
# conv2d_transpose_1/strided_slice_1/stack_2 [<tf.Tensor 'conv2d_transpose_1/strided_slice_1/stack_2:0' shape=(1,) dtype=int32>] 1
# ------
# conv2d_transpose_1/strided_slice_1 [<tf.Tensor 'conv2d_transpose_1/strided_slice_1:0' shape=() dtype=int32>] 1
# ------
# conv2d_transpose_1/strided_slice_2/stack [<tf.Tensor 'conv2d_transpose_1/strided_slice_2/stack:0' shape=(1,) dtype=int32>] 1
# ------
# conv2d_transpose_1/strided_slice_2/stack_1 [<tf.Tensor 'conv2d_transpose_1/strided_slice_2/stack_1:0' shape=(1,) dtype=int32>] 1
# ------
# conv2d_transpose_1/strided_slice_2/stack_2 [<tf.Tensor 'conv2d_transpose_1/strided_slice_2/stack_2:0' shape=(1,) dtype=int32>] 1
# ------
# conv2d_transpose_1/strided_slice_2 [<tf.Tensor 'conv2d_transpose_1/strided_slice_2:0' shape=() dtype=int32>] 1
# ------
# conv2d_transpose_1/mul/y [<tf.Tensor 'conv2d_transpose_1/mul/y:0' shape=() dtype=int32>] 1
# ------
# conv2d_transpose_1/mul [<tf.Tensor 'conv2d_transpose_1/mul:0' shape=() dtype=int32>] 1
# ------
# conv2d_transpose_1/mul_1/y [<tf.Tensor 'conv2d_transpose_1/mul_1/y:0' shape=() dtype=int32>] 1
# ------
# conv2d_transpose_1/mul_1 [<tf.Tensor 'conv2d_transpose_1/mul_1:0' shape=() dtype=int32>] 1
# ------
# conv2d_transpose_1/stack/3 [<tf.Tensor 'conv2d_transpose_1/stack/3:0' shape=() dtype=int32>] 1
# ------
# conv2d_transpose_1/stack [<tf.Tensor 'conv2d_transpose_1/stack:0' shape=(4,) dtype=int32>] 1
# ------
# conv2d_transpose_1/conv2d_transpose [<tf.Tensor 'conv2d_transpose_1/conv2d_transpose:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# conv2d_transpose_1/BiasAdd [<tf.Tensor 'conv2d_transpose_1/BiasAdd:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# mul_5/y [<tf.Tensor 'mul_5/y:0' shape=() dtype=float32>] 1
# ------
# mul_5 [<tf.Tensor 'mul_5:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# Maximum_5 [<tf.Tensor 'Maximum_5:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# dropout_5/keep_prob [<tf.Tensor 'dropout_5/keep_prob:0' shape=() dtype=float32>] 1
# ------
# dropout_5/Shape [<tf.Tensor 'dropout_5/Shape:0' shape=(4,) dtype=int32>] 1
# ------
# dropout_5/random_uniform/min [<tf.Tensor 'dropout_5/random_uniform/min:0' shape=() dtype=float32>] 1
# ------
# dropout_5/random_uniform/max [<tf.Tensor 'dropout_5/random_uniform/max:0' shape=() dtype=float32>] 1
# ------
# dropout_5/random_uniform/RandomUniform [<tf.Tensor 'dropout_5/random_uniform/RandomUniform:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# dropout_5/random_uniform/sub [<tf.Tensor 'dropout_5/random_uniform/sub:0' shape=() dtype=float32>] 1
# ------
# dropout_5/random_uniform/mul [<tf.Tensor 'dropout_5/random_uniform/mul:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# dropout_5/random_uniform [<tf.Tensor 'dropout_5/random_uniform:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# dropout_5/add [<tf.Tensor 'dropout_5/add:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# dropout_5/Floor [<tf.Tensor 'dropout_5/Floor:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# dropout_5/div [<tf.Tensor 'dropout_5/div:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# dropout_5/mul [<tf.Tensor 'dropout_5/mul:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# decoder_out/kernel/Initializer/truncated_normal/shape [<tf.Tensor 'decoder_out/kernel/Initializer/truncated_normal/shape:0' shape=(4,) dtype=int32>] 1
# ------
# decoder_out/kernel/Initializer/truncated_normal/mean [<tf.Tensor 'decoder_out/kernel/Initializer/truncated_normal/mean:0' shape=() dtype=float32>] 1
# ------
# decoder_out/kernel/Initializer/truncated_normal/stddev [<tf.Tensor 'decoder_out/kernel/Initializer/truncated_normal/stddev:0' shape=() dtype=float32>] 1
# ------
# decoder_out/kernel/Initializer/truncated_normal/TruncatedNormal [<tf.Tensor 'decoder_out/kernel/Initializer/truncated_normal/TruncatedNormal:0' shape=(5, 5, 1, 128) dtype=float32>] 1
# ------
# decoder_out/kernel/Initializer/truncated_normal/mul [<tf.Tensor 'decoder_out/kernel/Initializer/truncated_normal/mul:0' shape=(5, 5, 1, 128) dtype=float32>] 1
# ------
# decoder_out/kernel/Initializer/truncated_normal [<tf.Tensor 'decoder_out/kernel/Initializer/truncated_normal:0' shape=(5, 5, 1, 128) dtype=float32>] 1
# ------
# decoder_out/kernel [<tf.Tensor 'decoder_out/kernel:0' shape=(5, 5, 1, 128) dtype=float32_ref>] 1
# ------
# decoder_out/kernel/Assign [<tf.Tensor 'decoder_out/kernel/Assign:0' shape=(5, 5, 1, 128) dtype=float32_ref>] 1
# ------
# decoder_out/kernel/read [<tf.Tensor 'decoder_out/kernel/read:0' shape=(5, 5, 1, 128) dtype=float32>] 1
# ------
# decoder_out/bias/Initializer/zeros [<tf.Tensor 'decoder_out/bias/Initializer/zeros:0' shape=(1,) dtype=float32>] 1
# ------
# decoder_out/bias [<tf.Tensor 'decoder_out/bias:0' shape=(1,) dtype=float32_ref>] 1
# ------
# decoder_out/bias/Assign [<tf.Tensor 'decoder_out/bias/Assign:0' shape=(1,) dtype=float32_ref>] 1
# ------
# decoder_out/bias/read [<tf.Tensor 'decoder_out/bias/read:0' shape=(1,) dtype=float32>] 1
# ------
# decoder_out/Shape [<tf.Tensor 'decoder_out/Shape:0' shape=(4,) dtype=int32>] 1
# ------
# decoder_out/strided_slice/stack [<tf.Tensor 'decoder_out/strided_slice/stack:0' shape=(1,) dtype=int32>] 1
# ------
# decoder_out/strided_slice/stack_1 [<tf.Tensor 'decoder_out/strided_slice/stack_1:0' shape=(1,) dtype=int32>] 1
# ------
# decoder_out/strided_slice/stack_2 [<tf.Tensor 'decoder_out/strided_slice/stack_2:0' shape=(1,) dtype=int32>] 1
# ------
# decoder_out/strided_slice [<tf.Tensor 'decoder_out/strided_slice:0' shape=() dtype=int32>] 1
# ------
# decoder_out/strided_slice_1/stack [<tf.Tensor 'decoder_out/strided_slice_1/stack:0' shape=(1,) dtype=int32>] 1
# ------
# decoder_out/strided_slice_1/stack_1 [<tf.Tensor 'decoder_out/strided_slice_1/stack_1:0' shape=(1,) dtype=int32>] 1
# ------
# decoder_out/strided_slice_1/stack_2 [<tf.Tensor 'decoder_out/strided_slice_1/stack_2:0' shape=(1,) dtype=int32>] 1
# ------
# decoder_out/strided_slice_1 [<tf.Tensor 'decoder_out/strided_slice_1:0' shape=() dtype=int32>] 1
# ------
# decoder_out/strided_slice_2/stack [<tf.Tensor 'decoder_out/strided_slice_2/stack:0' shape=(1,) dtype=int32>] 1
# ------
# decoder_out/strided_slice_2/stack_1 [<tf.Tensor 'decoder_out/strided_slice_2/stack_1:0' shape=(1,) dtype=int32>] 1
# ------
# decoder_out/strided_slice_2/stack_2 [<tf.Tensor 'decoder_out/strided_slice_2/stack_2:0' shape=(1,) dtype=int32>] 1
# ------
# decoder_out/strided_slice_2 [<tf.Tensor 'decoder_out/strided_slice_2:0' shape=() dtype=int32>] 1
# ------
# decoder_out/mul/y [<tf.Tensor 'decoder_out/mul/y:0' shape=() dtype=int32>] 1
# ------
# decoder_out/mul [<tf.Tensor 'decoder_out/mul:0' shape=() dtype=int32>] 1
# ------
# decoder_out/mul_1/y [<tf.Tensor 'decoder_out/mul_1/y:0' shape=() dtype=int32>] 1
# ------
# decoder_out/mul_1 [<tf.Tensor 'decoder_out/mul_1:0' shape=() dtype=int32>] 1
# ------
# decoder_out/stack/3 [<tf.Tensor 'decoder_out/stack/3:0' shape=() dtype=int32>] 1
# ------
# decoder_out/stack [<tf.Tensor 'decoder_out/stack:0' shape=(4,) dtype=int32>] 1
# ------
# decoder_out/conv2d_transpose [<tf.Tensor 'decoder_out/conv2d_transpose:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# decoder_out/BiasAdd [<tf.Tensor 'decoder_out/BiasAdd:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# Sigmoid [<tf.Tensor 'Sigmoid:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# decoder_sigmoid [<tf.Tensor 'decoder_sigmoid:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# decoder_last [<tf.Tensor 'decoder_last:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# logistic_loss/zeros_like [<tf.Tensor 'logistic_loss/zeros_like:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# logistic_loss/GreaterEqual [<tf.Tensor 'logistic_loss/GreaterEqual:0' shape=(?, 32, 32, 1) dtype=bool>] 1
# ------
# logistic_loss/Select [<tf.Tensor 'logistic_loss/Select:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# logistic_loss/Neg [<tf.Tensor 'logistic_loss/Neg:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# logistic_loss/Select_1 [<tf.Tensor 'logistic_loss/Select_1:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# logistic_loss/mul [<tf.Tensor 'logistic_loss/mul:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# logistic_loss/sub [<tf.Tensor 'logistic_loss/sub:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# logistic_loss/Exp [<tf.Tensor 'logistic_loss/Exp:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# logistic_loss/Log1p [<tf.Tensor 'logistic_loss/Log1p:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# logistic_loss [<tf.Tensor 'logistic_loss:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# Sum/reduction_indices [<tf.Tensor 'Sum/reduction_indices:0' shape=(3,) dtype=int32>] 1
# ------
# Sum [<tf.Tensor 'Sum:0' shape=(?,) dtype=float32>] 1
# ------
# Const [<tf.Tensor 'Const:0' shape=(1,) dtype=int32>] 1
# ------
# Mean [<tf.Tensor 'Mean:0' shape=() dtype=float32>] 1
# ------
# gradients/Shape [<tf.Tensor 'gradients/Shape:0' shape=(0,) dtype=int32>] 1
# ------
# gradients/grad_ys_0 [<tf.Tensor 'gradients/grad_ys_0:0' shape=() dtype=float32>] 1
# ------
# gradients/Fill [<tf.Tensor 'gradients/Fill:0' shape=() dtype=float32>] 1
# ------
# gradients/Mean_grad/Reshape/shape [<tf.Tensor 'gradients/Mean_grad/Reshape/shape:0' shape=(1,) dtype=int32>] 1
# ------
# gradients/Mean_grad/Reshape [<tf.Tensor 'gradients/Mean_grad/Reshape:0' shape=(1,) dtype=float32>] 1
# ------
# gradients/Mean_grad/Shape [<tf.Tensor 'gradients/Mean_grad/Shape:0' shape=(1,) dtype=int32>] 1
# ------
# gradients/Mean_grad/Tile [<tf.Tensor 'gradients/Mean_grad/Tile:0' shape=(?,) dtype=float32>] 1
# ------
# gradients/Mean_grad/Shape_1 [<tf.Tensor 'gradients/Mean_grad/Shape_1:0' shape=(1,) dtype=int32>] 1
# ------
# gradients/Mean_grad/Shape_2 [<tf.Tensor 'gradients/Mean_grad/Shape_2:0' shape=(0,) dtype=int32>] 1
# ------
# gradients/Mean_grad/Const [<tf.Tensor 'gradients/Mean_grad/Const:0' shape=(1,) dtype=int32>] 1
# ------
# gradients/Mean_grad/Prod [<tf.Tensor 'gradients/Mean_grad/Prod:0' shape=() dtype=int32>] 1
# ------
# gradients/Mean_grad/Const_1 [<tf.Tensor 'gradients/Mean_grad/Const_1:0' shape=(1,) dtype=int32>] 1
# ------
# gradients/Mean_grad/Prod_1 [<tf.Tensor 'gradients/Mean_grad/Prod_1:0' shape=() dtype=int32>] 1
# ------
# gradients/Mean_grad/Maximum/y [<tf.Tensor 'gradients/Mean_grad/Maximum/y:0' shape=() dtype=int32>] 1
# ------
# gradients/Mean_grad/Maximum [<tf.Tensor 'gradients/Mean_grad/Maximum:0' shape=() dtype=int32>] 1
# ------
# gradients/Mean_grad/floordiv [<tf.Tensor 'gradients/Mean_grad/floordiv:0' shape=() dtype=int32>] 1
# ------
# gradients/Mean_grad/Cast [<tf.Tensor 'gradients/Mean_grad/Cast:0' shape=() dtype=float32>] 1
# ------
# gradients/Mean_grad/truediv [<tf.Tensor 'gradients/Mean_grad/truediv:0' shape=(?,) dtype=float32>] 1
# ------
# gradients/Sum_grad/Shape [<tf.Tensor 'gradients/Sum_grad/Shape:0' shape=(4,) dtype=int32>] 1
# ------
# gradients/Sum_grad/Size [<tf.Tensor 'gradients/Sum_grad/Size:0' shape=() dtype=int32>] 1
# ------
# gradients/Sum_grad/add [<tf.Tensor 'gradients/Sum_grad/add:0' shape=(3,) dtype=int32>] 1
# ------
# gradients/Sum_grad/mod [<tf.Tensor 'gradients/Sum_grad/mod:0' shape=(3,) dtype=int32>] 1
# ------
# gradients/Sum_grad/Shape_1 [<tf.Tensor 'gradients/Sum_grad/Shape_1:0' shape=(1,) dtype=int32>] 1
# ------
# gradients/Sum_grad/range/start [<tf.Tensor 'gradients/Sum_grad/range/start:0' shape=() dtype=int32>] 1
# ------
# gradients/Sum_grad/range/delta [<tf.Tensor 'gradients/Sum_grad/range/delta:0' shape=() dtype=int32>] 1
# ------
# gradients/Sum_grad/range [<tf.Tensor 'gradients/Sum_grad/range:0' shape=(4,) dtype=int32>] 1
# ------
# gradients/Sum_grad/Fill/value [<tf.Tensor 'gradients/Sum_grad/Fill/value:0' shape=() dtype=int32>] 1
# ------
# gradients/Sum_grad/Fill [<tf.Tensor 'gradients/Sum_grad/Fill:0' shape=(3,) dtype=int32>] 1
# ------
# gradients/Sum_grad/DynamicStitch [<tf.Tensor 'gradients/Sum_grad/DynamicStitch:0' shape=(4,) dtype=int32>] 1
# ------
# gradients/Sum_grad/Maximum/y [<tf.Tensor 'gradients/Sum_grad/Maximum/y:0' shape=() dtype=int32>] 1
# ------
# gradients/Sum_grad/Maximum [<tf.Tensor 'gradients/Sum_grad/Maximum:0' shape=(4,) dtype=int32>] 1
# ------
# gradients/Sum_grad/floordiv [<tf.Tensor 'gradients/Sum_grad/floordiv:0' shape=(4,) dtype=int32>] 1
# ------
# gradients/Sum_grad/Reshape [<tf.Tensor 'gradients/Sum_grad/Reshape:0' shape=(?, ?, ?, ?) dtype=float32>] 1
# ------
# gradients/Sum_grad/Tile [<tf.Tensor 'gradients/Sum_grad/Tile:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss_grad/Shape [<tf.Tensor 'gradients/logistic_loss_grad/Shape:0' shape=(4,) dtype=int32>] 1
# ------
# gradients/logistic_loss_grad/Shape_1 [<tf.Tensor 'gradients/logistic_loss_grad/Shape_1:0' shape=(4,) dtype=int32>] 1
# ------
# gradients/logistic_loss_grad/BroadcastGradientArgs [<tf.Tensor 'gradients/logistic_loss_grad/BroadcastGradientArgs:0' shape=(?,) dtype=int32>, <tf.Tensor 'gradients/logistic_loss_grad/BroadcastGradientArgs:1' shape=(?,) dtype=int32>] 2
# ------
# gradients/logistic_loss_grad/Sum [<tf.Tensor 'gradients/logistic_loss_grad/Sum:0' shape=<unknown> dtype=float32>] 1
# ------
# gradients/logistic_loss_grad/Reshape [<tf.Tensor 'gradients/logistic_loss_grad/Reshape:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss_grad/Sum_1 [<tf.Tensor 'gradients/logistic_loss_grad/Sum_1:0' shape=<unknown> dtype=float32>] 1
# ------
# gradients/logistic_loss_grad/Reshape_1 [<tf.Tensor 'gradients/logistic_loss_grad/Reshape_1:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss_grad/tuple/group_deps [] 0
# ------
# gradients/logistic_loss_grad/tuple/control_dependency [<tf.Tensor 'gradients/logistic_loss_grad/tuple/control_dependency:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss_grad/tuple/control_dependency_1 [<tf.Tensor 'gradients/logistic_loss_grad/tuple/control_dependency_1:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss/sub_grad/Shape [<tf.Tensor 'gradients/logistic_loss/sub_grad/Shape:0' shape=(4,) dtype=int32>] 1
# ------
# gradients/logistic_loss/sub_grad/Shape_1 [<tf.Tensor 'gradients/logistic_loss/sub_grad/Shape_1:0' shape=(4,) dtype=int32>] 1
# ------
# gradients/logistic_loss/sub_grad/BroadcastGradientArgs [<tf.Tensor 'gradients/logistic_loss/sub_grad/BroadcastGradientArgs:0' shape=(?,) dtype=int32>, <tf.Tensor 'gradients/logistic_loss/sub_grad/BroadcastGradientArgs:1' shape=(?,) dtype=int32>] 2
# ------
# gradients/logistic_loss/sub_grad/Sum [<tf.Tensor 'gradients/logistic_loss/sub_grad/Sum:0' shape=<unknown> dtype=float32>] 1
# ------
# gradients/logistic_loss/sub_grad/Reshape [<tf.Tensor 'gradients/logistic_loss/sub_grad/Reshape:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss/sub_grad/Sum_1 [<tf.Tensor 'gradients/logistic_loss/sub_grad/Sum_1:0' shape=<unknown> dtype=float32>] 1
# ------
# gradients/logistic_loss/sub_grad/Neg [<tf.Tensor 'gradients/logistic_loss/sub_grad/Neg:0' shape=<unknown> dtype=float32>] 1
# ------
# gradients/logistic_loss/sub_grad/Reshape_1 [<tf.Tensor 'gradients/logistic_loss/sub_grad/Reshape_1:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss/sub_grad/tuple/group_deps [] 0
# ------
# gradients/logistic_loss/sub_grad/tuple/control_dependency [<tf.Tensor 'gradients/logistic_loss/sub_grad/tuple/control_dependency:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss/sub_grad/tuple/control_dependency_1 [<tf.Tensor 'gradients/logistic_loss/sub_grad/tuple/control_dependency_1:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss/Log1p_grad/add/x [<tf.Tensor 'gradients/logistic_loss/Log1p_grad/add/x:0' shape=() dtype=float32>] 1
# ------
# gradients/logistic_loss/Log1p_grad/add [<tf.Tensor 'gradients/logistic_loss/Log1p_grad/add:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss/Log1p_grad/Reciprocal [<tf.Tensor 'gradients/logistic_loss/Log1p_grad/Reciprocal:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss/Log1p_grad/mul [<tf.Tensor 'gradients/logistic_loss/Log1p_grad/mul:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss/Select_grad/zeros_like [<tf.Tensor 'gradients/logistic_loss/Select_grad/zeros_like:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss/Select_grad/Select [<tf.Tensor 'gradients/logistic_loss/Select_grad/Select:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss/Select_grad/Select_1 [<tf.Tensor 'gradients/logistic_loss/Select_grad/Select_1:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss/Select_grad/tuple/group_deps [] 0
# ------
# gradients/logistic_loss/Select_grad/tuple/control_dependency [<tf.Tensor 'gradients/logistic_loss/Select_grad/tuple/control_dependency:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss/Select_grad/tuple/control_dependency_1 [<tf.Tensor 'gradients/logistic_loss/Select_grad/tuple/control_dependency_1:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss/mul_grad/Shape [<tf.Tensor 'gradients/logistic_loss/mul_grad/Shape:0' shape=(4,) dtype=int32>] 1
# ------
# gradients/logistic_loss/mul_grad/Shape_1 [<tf.Tensor 'gradients/logistic_loss/mul_grad/Shape_1:0' shape=(4,) dtype=int32>] 1
# ------
# gradients/logistic_loss/mul_grad/BroadcastGradientArgs [<tf.Tensor 'gradients/logistic_loss/mul_grad/BroadcastGradientArgs:0' shape=(?,) dtype=int32>, <tf.Tensor 'gradients/logistic_loss/mul_grad/BroadcastGradientArgs:1' shape=(?,) dtype=int32>] 2
# ------
# gradients/logistic_loss/mul_grad/Mul [<tf.Tensor 'gradients/logistic_loss/mul_grad/Mul:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss/mul_grad/Sum [<tf.Tensor 'gradients/logistic_loss/mul_grad/Sum:0' shape=<unknown> dtype=float32>] 1
# ------
# gradients/logistic_loss/mul_grad/Reshape [<tf.Tensor 'gradients/logistic_loss/mul_grad/Reshape:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss/mul_grad/Mul_1 [<tf.Tensor 'gradients/logistic_loss/mul_grad/Mul_1:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss/mul_grad/Sum_1 [<tf.Tensor 'gradients/logistic_loss/mul_grad/Sum_1:0' shape=<unknown> dtype=float32>] 1
# ------
# gradients/logistic_loss/mul_grad/Reshape_1 [<tf.Tensor 'gradients/logistic_loss/mul_grad/Reshape_1:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss/mul_grad/tuple/group_deps [] 0
# ------
# gradients/logistic_loss/mul_grad/tuple/control_dependency [<tf.Tensor 'gradients/logistic_loss/mul_grad/tuple/control_dependency:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss/mul_grad/tuple/control_dependency_1 [<tf.Tensor 'gradients/logistic_loss/mul_grad/tuple/control_dependency_1:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss/Exp_grad/mul [<tf.Tensor 'gradients/logistic_loss/Exp_grad/mul:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss/Select_1_grad/zeros_like [<tf.Tensor 'gradients/logistic_loss/Select_1_grad/zeros_like:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss/Select_1_grad/Select [<tf.Tensor 'gradients/logistic_loss/Select_1_grad/Select:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss/Select_1_grad/Select_1 [<tf.Tensor 'gradients/logistic_loss/Select_1_grad/Select_1:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss/Select_1_grad/tuple/group_deps [] 0
# ------
# gradients/logistic_loss/Select_1_grad/tuple/control_dependency [<tf.Tensor 'gradients/logistic_loss/Select_1_grad/tuple/control_dependency:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss/Select_1_grad/tuple/control_dependency_1 [<tf.Tensor 'gradients/logistic_loss/Select_1_grad/tuple/control_dependency_1:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/logistic_loss/Neg_grad/Neg [<tf.Tensor 'gradients/logistic_loss/Neg_grad/Neg:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/AddN [<tf.Tensor 'gradients/AddN:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/decoder_out/BiasAdd_grad/BiasAddGrad [<tf.Tensor 'gradients/decoder_out/BiasAdd_grad/BiasAddGrad:0' shape=(1,) dtype=float32>] 1
# ------
# gradients/decoder_out/BiasAdd_grad/tuple/group_deps [] 0
# ------
# gradients/decoder_out/BiasAdd_grad/tuple/control_dependency [<tf.Tensor 'gradients/decoder_out/BiasAdd_grad/tuple/control_dependency:0' shape=(?, 32, 32, 1) dtype=float32>] 1
# ------
# gradients/decoder_out/BiasAdd_grad/tuple/control_dependency_1 [<tf.Tensor 'gradients/decoder_out/BiasAdd_grad/tuple/control_dependency_1:0' shape=(1,) dtype=float32>] 1
# ------
# gradients/decoder_out/conv2d_transpose_grad/Shape [<tf.Tensor 'gradients/decoder_out/conv2d_transpose_grad/Shape:0' shape=(4,) dtype=int32>] 1
# ------
# gradients/decoder_out/conv2d_transpose_grad/Conv2DBackpropFilter [<tf.Tensor 'gradients/decoder_out/conv2d_transpose_grad/Conv2DBackpropFilter:0' shape=(5, 5, 1, 128) dtype=float32>] 1
# ------
# gradients/decoder_out/conv2d_transpose_grad/Conv2D [<tf.Tensor 'gradients/decoder_out/conv2d_transpose_grad/Conv2D:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# gradients/decoder_out/conv2d_transpose_grad/tuple/group_deps [] 0
# ------
# gradients/decoder_out/conv2d_transpose_grad/tuple/control_dependency [<tf.Tensor 'gradients/decoder_out/conv2d_transpose_grad/tuple/control_dependency:0' shape=(5, 5, 1, 128) dtype=float32>] 1
# ------
# gradients/decoder_out/conv2d_transpose_grad/tuple/control_dependency_1 [<tf.Tensor 'gradients/decoder_out/conv2d_transpose_grad/tuple/control_dependency_1:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# gradients/dropout_5/mul_grad/Shape [<tf.Tensor 'gradients/dropout_5/mul_grad/Shape:0' shape=(4,) dtype=int32>] 1
# ------
# gradients/dropout_5/mul_grad/Shape_1 [<tf.Tensor 'gradients/dropout_5/mul_grad/Shape_1:0' shape=(4,) dtype=int32>] 1
# ------
# gradients/dropout_5/mul_grad/BroadcastGradientArgs [<tf.Tensor 'gradients/dropout_5/mul_grad/BroadcastGradientArgs:0' shape=(?,) dtype=int32>, <tf.Tensor 'gradients/dropout_5/mul_grad/BroadcastGradientArgs:1' shape=(?,) dtype=int32>] 2
# ------
# gradients/dropout_5/mul_grad/Mul [<tf.Tensor 'gradients/dropout_5/mul_grad/Mul:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# gradients/dropout_5/mul_grad/Sum [<tf.Tensor 'gradients/dropout_5/mul_grad/Sum:0' shape=<unknown> dtype=float32>] 1
# ------
# gradients/dropout_5/mul_grad/Reshape [<tf.Tensor 'gradients/dropout_5/mul_grad/Reshape:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# gradients/dropout_5/mul_grad/Mul_1 [<tf.Tensor 'gradients/dropout_5/mul_grad/Mul_1:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# gradients/dropout_5/mul_grad/Sum_1 [<tf.Tensor 'gradients/dropout_5/mul_grad/Sum_1:0' shape=<unknown> dtype=float32>] 1
# ------
# gradients/dropout_5/mul_grad/Reshape_1 [<tf.Tensor 'gradients/dropout_5/mul_grad/Reshape_1:0' shape=(?, 16, 16, 128) dtype=float32>] 1
# ------
# gradients/dropout_5/mul_grad/tuple/group_deps [] 0
# ------
# ...
# ------
# conv2d_transpose_1/kernel/Adam_1/Initializer/zeros/shape_as_tensor [<tf.Tensor 'conv2d_transpose_1/kernel/Adam_1/Initializer/zeros/shape_as_tensor:0' shape=(4,) dtype=int32>] 1
# ------
# conv2d_transpose_1/kernel/Adam_1/Initializer/zeros/Const [<tf.Tensor 'conv2d_transpose_1/kernel/Adam_1/Initializer/zeros/Const:0' shape=() dtype=float32>] 1
# ------
# conv2d_transpose_1/kernel/Adam_1/Initializer/zeros [<tf.Tensor 'conv2d_transpose_1/kernel/Adam_1/Initializer/zeros:0' shape=(3, 3, 128, 256) dtype=float32>] 1
# ------
# conv2d_transpose_1/kernel/Adam_1 [<tf.Tensor 'conv2d_transpose_1/kernel/Adam_1:0' shape=(3, 3, 128, 256) dtype=float32_ref>] 1
# ------
# conv2d_transpose_1/kernel/Adam_1/Assign [<tf.Tensor 'conv2d_transpose_1/kernel/Adam_1/Assign:0' shape=(3, 3, 128, 256) dtype=float32_ref>] 1
# ------
# conv2d_transpose_1/kernel/Adam_1/read [<tf.Tensor 'conv2d_transpose_1/kernel/Adam_1/read:0' shape=(3, 3, 128, 256) dtype=float32>] 1
# ------
# conv2d_transpose_1/bias/Adam/Initializer/zeros [<tf.Tensor 'conv2d_transpose_1/bias/Adam/Initializer/zeros:0' shape=(128,) dtype=float32>] 1
# ------
# conv2d_transpose_1/bias/Adam [<tf.Tensor 'conv2d_transpose_1/bias/Adam:0' shape=(128,) dtype=float32_ref>] 1
# ------
# conv2d_transpose_1/bias/Adam/Assign [<tf.Tensor 'conv2d_transpose_1/bias/Adam/Assign:0' shape=(128,) dtype=float32_ref>] 1
# ------
# conv2d_transpose_1/bias/Adam/read [<tf.Tensor 'conv2d_transpose_1/bias/Adam/read:0' shape=(128,) dtype=float32>] 1
# ------
# conv2d_transpose_1/bias/Adam_1/Initializer/zeros [<tf.Tensor 'conv2d_transpose_1/bias/Adam_1/Initializer/zeros:0' shape=(128,) dtype=float32>] 1
# ------
# conv2d_transpose_1/bias/Adam_1 [<tf.Tensor 'conv2d_transpose_1/bias/Adam_1:0' shape=(128,) dtype=float32_ref>] 1
# ------
# conv2d_transpose_1/bias/Adam_1/Assign [<tf.Tensor 'conv2d_transpose_1/bias/Adam_1/Assign:0' shape=(128,) dtype=float32_ref>] 1
# ------
# conv2d_transpose_1/bias/Adam_1/read [<tf.Tensor 'conv2d_transpose_1/bias/Adam_1/read:0' shape=(128,) dtype=float32>] 1
# ------
# decoder_out/kernel/Adam/Initializer/zeros/shape_as_tensor [<tf.Tensor 'decoder_out/kernel/Adam/Initializer/zeros/shape_as_tensor:0' shape=(4,) dtype=int32>] 1
# ------
# decoder_out/kernel/Adam/Initializer/zeros/Const [<tf.Tensor 'decoder_out/kernel/Adam/Initializer/zeros/Const:0' shape=() dtype=float32>] 1
# ------
# decoder_out/kernel/Adam/Initializer/zeros [<tf.Tensor 'decoder_out/kernel/Adam/Initializer/zeros:0' shape=(5, 5, 1, 128) dtype=float32>] 1
# ------
# decoder_out/kernel/Adam [<tf.Tensor 'decoder_out/kernel/Adam:0' shape=(5, 5, 1, 128) dtype=float32_ref>] 1
# ------
# decoder_out/kernel/Adam/Assign [<tf.Tensor 'decoder_out/kernel/Adam/Assign:0' shape=(5, 5, 1, 128) dtype=float32_ref>] 1
# ------
# decoder_out/kernel/Adam/read [<tf.Tensor 'decoder_out/kernel/Adam/read:0' shape=(5, 5, 1, 128) dtype=float32>] 1
# ------
# decoder_out/kernel/Adam_1/Initializer/zeros/shape_as_tensor [<tf.Tensor 'decoder_out/kernel/Adam_1/Initializer/zeros/shape_as_tensor:0' shape=(4,) dtype=int32>] 1
# ------
# decoder_out/kernel/Adam_1/Initializer/zeros/Const [<tf.Tensor 'decoder_out/kernel/Adam_1/Initializer/zeros/Const:0' shape=() dtype=float32>] 1
# ------
# decoder_out/kernel/Adam_1/Initializer/zeros [<tf.Tensor 'decoder_out/kernel/Adam_1/Initializer/zeros:0' shape=(5, 5, 1, 128) dtype=float32>] 1
# ------
# decoder_out/kernel/Adam_1 [<tf.Tensor 'decoder_out/kernel/Adam_1:0' shape=(5, 5, 1, 128) dtype=float32_ref>] 1
# ------
# decoder_out/kernel/Adam_1/Assign [<tf.Tensor 'decoder_out/kernel/Adam_1/Assign:0' shape=(5, 5, 1, 128) dtype=float32_ref>] 1
# ------
# decoder_out/kernel/Adam_1/read [<tf.Tensor 'decoder_out/kernel/Adam_1/read:0' shape=(5, 5, 1, 128) dtype=float32>] 1
# ------
# decoder_out/bias/Adam/Initializer/zeros [<tf.Tensor 'decoder_out/bias/Adam/Initializer/zeros:0' shape=(1,) dtype=float32>] 1
# ------
# decoder_out/bias/Adam [<tf.Tensor 'decoder_out/bias/Adam:0' shape=(1,) dtype=float32_ref>] 1
# ------
# decoder_out/bias/Adam/Assign [<tf.Tensor 'decoder_out/bias/Adam/Assign:0' shape=(1,) dtype=float32_ref>] 1
# ------
# decoder_out/bias/Adam/read [<tf.Tensor 'decoder_out/bias/Adam/read:0' shape=(1,) dtype=float32>] 1
# ------
# decoder_out/bias/Adam_1/Initializer/zeros [<tf.Tensor 'decoder_out/bias/Adam_1/Initializer/zeros:0' shape=(1,) dtype=float32>] 1
# ------
# decoder_out/bias/Adam_1 [<tf.Tensor 'decoder_out/bias/Adam_1:0' shape=(1,) dtype=float32_ref>] 1
# ------
# decoder_out/bias/Adam_1/Assign [<tf.Tensor 'decoder_out/bias/Adam_1/Assign:0' shape=(1,) dtype=float32_ref>] 1
# ------
# decoder_out/bias/Adam_1/read [<tf.Tensor 'decoder_out/bias/Adam_1/read:0' shape=(1,) dtype=float32>] 1
# ------
# Adam/learning_rate [<tf.Tensor 'Adam/learning_rate:0' shape=() dtype=float32>] 1
# ------
# Adam/beta1 [<tf.Tensor 'Adam/beta1:0' shape=() dtype=float32>] 1
# ------
# Adam/beta2 [<tf.Tensor 'Adam/beta2:0' shape=() dtype=float32>] 1
# ------
# Adam/epsilon [<tf.Tensor 'Adam/epsilon:0' shape=() dtype=float32>] 1
# ------
# Adam/update_filter_00/kernel/ApplyAdam [<tf.Tensor 'Adam/update_filter_00/kernel/ApplyAdam:0' shape=(3, 3, 1, 128) dtype=float32_ref>] 1
# ------
# Adam/update_filter_00/bias/ApplyAdam [<tf.Tensor 'Adam/update_filter_00/bias/ApplyAdam:0' shape=(128,) dtype=float32_ref>] 1
# ------
# Adam/update_filter_01/kernel/ApplyAdam [<tf.Tensor 'Adam/update_filter_01/kernel/ApplyAdam:0' shape=(3, 3, 128, 256) dtype=float32_ref>] 1
# ------
# Adam/update_filter_01/bias/ApplyAdam [<tf.Tensor 'Adam/update_filter_01/bias/ApplyAdam:0' shape=(256,) dtype=float32_ref>] 1
# ------
# Adam/update_filter_02/kernel/ApplyAdam [<tf.Tensor 'Adam/update_filter_02/kernel/ApplyAdam:0' shape=(3, 3, 256, 512) dtype=float32_ref>] 1
# ------
# Adam/update_filter_02/bias/ApplyAdam [<tf.Tensor 'Adam/update_filter_02/bias/ApplyAdam:0' shape=(512,) dtype=float32_ref>] 1
# ------
# Adam/update_latent_space/kernel/ApplyAdam [<tf.Tensor 'Adam/update_latent_space/kernel/ApplyAdam:0' shape=(8192, 128) dtype=float32_ref>] 1
# ------
# Adam/update_latent_space/bias/ApplyAdam [<tf.Tensor 'Adam/update_latent_space/bias/ApplyAdam:0' shape=(128,) dtype=float32_ref>] 1
# ------
# Adam/update_dense/kernel/ApplyAdam [<tf.Tensor 'Adam/update_dense/kernel/ApplyAdam:0' shape=(128, 8192) dtype=float32_ref>] 1
# ------
# Adam/update_dense/bias/ApplyAdam [<tf.Tensor 'Adam/update_dense/bias/ApplyAdam:0' shape=(8192,) dtype=float32_ref>] 1
# ------
# Adam/update_conv2d_transpose/kernel/ApplyAdam [<tf.Tensor 'Adam/update_conv2d_transpose/kernel/ApplyAdam:0' shape=(3, 3, 256, 512) dtype=float32_ref>] 1
# ------
# Adam/update_conv2d_transpose/bias/ApplyAdam [<tf.Tensor 'Adam/update_conv2d_transpose/bias/ApplyAdam:0' shape=(256,) dtype=float32_ref>] 1
# ------
# Adam/update_conv2d_transpose_1/kernel/ApplyAdam [<tf.Tensor 'Adam/update_conv2d_transpose_1/kernel/ApplyAdam:0' shape=(3, 3, 128, 256) dtype=float32_ref>] 1
# ------
# Adam/update_conv2d_transpose_1/bias/ApplyAdam [<tf.Tensor 'Adam/update_conv2d_transpose_1/bias/ApplyAdam:0' shape=(128,) dtype=float32_ref>] 1
# ------
# Adam/update_decoder_out/kernel/ApplyAdam [<tf.Tensor 'Adam/update_decoder_out/kernel/ApplyAdam:0' shape=(5, 5, 1, 128) dtype=float32_ref>] 1
# ------
# Adam/update_decoder_out/bias/ApplyAdam [<tf.Tensor 'Adam/update_decoder_out/bias/ApplyAdam:0' shape=(1,) dtype=float32_ref>] 1
# ------
# Adam/mul [<tf.Tensor 'Adam/mul:0' shape=() dtype=float32>] 1
# ------
# Adam/Assign [<tf.Tensor 'Adam/Assign:0' shape=() dtype=float32_ref>] 1
# ------
# Adam/mul_1 [<tf.Tensor 'Adam/mul_1:0' shape=() dtype=float32>] 1
# ------
# Adam/Assign_1 [<tf.Tensor 'Adam/Assign_1:0' shape=() dtype=float32_ref>] 1
# ------
# Adam [] 0
# ------
# save/Const [<tf.Tensor 'save/Const:0' shape=() dtype=string>] 1
# ------
# save/SaveV2/tensor_names [<tf.Tensor 'save/SaveV2/tensor_names:0' shape=(50,) dtype=string>] 1
# ------
# save/SaveV2/shape_and_slices [<tf.Tensor 'save/SaveV2/shape_and_slices:0' shape=(50,) dtype=string>] 1
# ------
# save/SaveV2 [] 0
# ------
# save/control_dependency [<tf.Tensor 'save/control_dependency:0' shape=() dtype=string>] 1
# ------
# save/RestoreV2/tensor_names [<tf.Tensor 'save/RestoreV2/tensor_names:0' shape=(50,) dtype=string>] 1
# ------
# save/RestoreV2/shape_and_slices [<tf.Tensor 'save/RestoreV2/shape_and_slices:0' shape=(50,) dtype=string>] 1
# ------
# save/RestoreV2 [<tf.Tensor 'save/RestoreV2:0' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:1' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:2' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:3' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:4' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:5' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:6' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:7' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:8' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:9' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:10' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:11' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:12' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:13' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:14' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:15' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:16' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:17' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:18' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:19' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:20' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:21' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:22' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:23' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:24' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:25' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:26' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:27' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:28' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:29' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:30' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:31' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:32' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:33' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:34' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:35' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:36' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:37' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:38' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:39' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:40' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:41' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:42' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:43' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:44' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:45' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:46' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:47' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:48' shape=<unknown> dtype=float32>, <tf.Tensor 'save/RestoreV2:49' shape=<unknown> dtype=float32>] 50
# ------
# save/Assign [<tf.Tensor 'save/Assign:0' shape=() dtype=float32_ref>] 1
# ------
# save/Assign_1 [<tf.Tensor 'save/Assign_1:0' shape=() dtype=float32_ref>] 1
# ------
# save/Assign_2 [<tf.Tensor 'save/Assign_2:0' shape=(256,) dtype=float32_ref>] 1
# ------
# save/Assign_3 [<tf.Tensor 'save/Assign_3:0' shape=(256,) dtype=float32_ref>] 1
# ------
# save/Assign_4 [<tf.Tensor 'save/Assign_4:0' shape=(256,) dtype=float32_ref>] 1
# ------
# save/Assign_5 [<tf.Tensor 'save/Assign_5:0' shape=(3, 3, 256, 512) dtype=float32_ref>] 1
# ------
# save/Assign_6 [<tf.Tensor 'save/Assign_6:0' shape=(3, 3, 256, 512) dtype=float32_ref>] 1
# ------
# save/Assign_7 [<tf.Tensor 'save/Assign_7:0' shape=(3, 3, 256, 512) dtype=float32_ref>] 1
# ------
# save/Assign_8 [<tf.Tensor 'save/Assign_8:0' shape=(128,) dtype=float32_ref>] 1
# ------
# save/Assign_9 [<tf.Tensor 'save/Assign_9:0' shape=(128,) dtype=float32_ref>] 1
# ------
# save/Assign_10 [<tf.Tensor 'save/Assign_10:0' shape=(128,) dtype=float32_ref>] 1
# ------
# save/Assign_11 [<tf.Tensor 'save/Assign_11:0' shape=(3, 3, 128, 256) dtype=float32_ref>] 1
# ------
# save/Assign_12 [<tf.Tensor 'save/Assign_12:0' shape=(3, 3, 128, 256) dtype=float32_ref>] 1
# ------
# save/Assign_13 [<tf.Tensor 'save/Assign_13:0' shape=(3, 3, 128, 256) dtype=float32_ref>] 1
# ------
# save/Assign_14 [<tf.Tensor 'save/Assign_14:0' shape=(1,) dtype=float32_ref>] 1
# ------
# save/Assign_15 [<tf.Tensor 'save/Assign_15:0' shape=(1,) dtype=float32_ref>] 1
# ------
# save/Assign_16 [<tf.Tensor 'save/Assign_16:0' shape=(1,) dtype=float32_ref>] 1
# ------
# save/Assign_17 [<tf.Tensor 'save/Assign_17:0' shape=(5, 5, 1, 128) dtype=float32_ref>] 1
# ------
# save/Assign_18 [<tf.Tensor 'save/Assign_18:0' shape=(5, 5, 1, 128) dtype=float32_ref>] 1
# ------
# save/Assign_19 [<tf.Tensor 'save/Assign_19:0' shape=(5, 5, 1, 128) dtype=float32_ref>] 1
# ------
# save/Assign_20 [<tf.Tensor 'save/Assign_20:0' shape=(8192,) dtype=float32_ref>] 1
# ------
# save/Assign_21 [<tf.Tensor 'save/Assign_21:0' shape=(8192,) dtype=float32_ref>] 1
# ------
# save/Assign_22 [<tf.Tensor 'save/Assign_22:0' shape=(8192,) dtype=float32_ref>] 1
# ------
# save/Assign_23 [<tf.Tensor 'save/Assign_23:0' shape=(128, 8192) dtype=float32_ref>] 1
# ------
# save/Assign_24 [<tf.Tensor 'save/Assign_24:0' shape=(128, 8192) dtype=float32_ref>] 1
# ------
# save/Assign_25 [<tf.Tensor 'save/Assign_25:0' shape=(128, 8192) dtype=float32_ref>] 1
# ------
# save/Assign_26 [<tf.Tensor 'save/Assign_26:0' shape=(128,) dtype=float32_ref>] 1
# ------
# save/Assign_27 [<tf.Tensor 'save/Assign_27:0' shape=(128,) dtype=float32_ref>] 1
# ------
# save/Assign_28 [<tf.Tensor 'save/Assign_28:0' shape=(128,) dtype=float32_ref>] 1
# ------
# save/Assign_29 [<tf.Tensor 'save/Assign_29:0' shape=(3, 3, 1, 128) dtype=float32_ref>] 1
# ------
# save/Assign_30 [<tf.Tensor 'save/Assign_30:0' shape=(3, 3, 1, 128) dtype=float32_ref>] 1
# ------
# save/Assign_31 [<tf.Tensor 'save/Assign_31:0' shape=(3, 3, 1, 128) dtype=float32_ref>] 1
# ------
# save/Assign_32 [<tf.Tensor 'save/Assign_32:0' shape=(256,) dtype=float32_ref>] 1
# ------
# save/Assign_33 [<tf.Tensor 'save/Assign_33:0' shape=(256,) dtype=float32_ref>] 1
# ------
# save/Assign_34 [<tf.Tensor 'save/Assign_34:0' shape=(256,) dtype=float32_ref>] 1
# ------
# save/Assign_35 [<tf.Tensor 'save/Assign_35:0' shape=(3, 3, 128, 256) dtype=float32_ref>] 1
# ------
# save/Assign_36 [<tf.Tensor 'save/Assign_36:0' shape=(3, 3, 128, 256) dtype=float32_ref>] 1
# ------
# save/Assign_37 [<tf.Tensor 'save/Assign_37:0' shape=(3, 3, 128, 256) dtype=float32_ref>] 1
# ------
# save/Assign_38 [<tf.Tensor 'save/Assign_38:0' shape=(512,) dtype=float32_ref>] 1
# ------
# save/Assign_39 [<tf.Tensor 'save/Assign_39:0' shape=(512,) dtype=float32_ref>] 1
# ------
# save/Assign_40 [<tf.Tensor 'save/Assign_40:0' shape=(512,) dtype=float32_ref>] 1
# ------
# save/Assign_41 [<tf.Tensor 'save/Assign_41:0' shape=(3, 3, 256, 512) dtype=float32_ref>] 1
# ------
# save/Assign_42 [<tf.Tensor 'save/Assign_42:0' shape=(3, 3, 256, 512) dtype=float32_ref>] 1
# ------
# save/Assign_43 [<tf.Tensor 'save/Assign_43:0' shape=(3, 3, 256, 512) dtype=float32_ref>] 1
# ------
# save/Assign_44 [<tf.Tensor 'save/Assign_44:0' shape=(128,) dtype=float32_ref>] 1
# ------
# save/Assign_45 [<tf.Tensor 'save/Assign_45:0' shape=(128,) dtype=float32_ref>] 1
# ------
# save/Assign_46 [<tf.Tensor 'save/Assign_46:0' shape=(128,) dtype=float32_ref>] 1
# ------
# save/Assign_47 [<tf.Tensor 'save/Assign_47:0' shape=(8192, 128) dtype=float32_ref>] 1
# ------
# save/Assign_48 [<tf.Tensor 'save/Assign_48:0' shape=(8192, 128) dtype=float32_ref>] 1
# ------
# save/Assign_49 [<tf.Tensor 'save/Assign_49:0' shape=(8192, 128) dtype=float32_ref>] 1
# ------
# save/restore_all [] 0
# ------
# init_1 [] 0
# ------

# %%
images = sess.graph.get_tensor_by_name('Placeholder:0')
enc = sess.graph.get_tensor_by_name('latent_space/BiasAdd:0')
sdd = sess.graph.get_tensor_by_name('decoder_sigmoid:0')
dd = sess.graph.get_tensor_by_name('decoder_last:0')

# %%
#datadir = "/media/cjw/Data/cyto/mmFromTifs/"
#datadir = "/home/cjw/disk2cjw/Data/yeast/"
mmfiles = utils.list_mmfiles(datadir)
print(mmfiles)

mmdict = dict()

n_all_images = 0
for mmfilename in mmfiles:
#mmfilename = datadir + "Fish6_15_cjw_mean_zero.mm"
#mmfilename = datadir + "mmplate15-1.mm"
    mmheader = np.memmap(mmfilename, dtype="int32", mode='r',
                    shape=(4,))

    header_shape = mmheader.shape
    #print(header_shape, mmheader)
    xshape = [mmheader[0], mmheader[1], mmheader[2], mmheader[3]]
    xshape = tuple(xshape)
    del mmheader
    n_all_images += xshape[0]
    
    m3 = np.memmap(mmfilename, dtype='float32', offset=128,
              mode='r', shape=xshape)
    key = mmfilename.split("/")[-1]
    mmdict[key] = m3

print(n_all_images)
mmdict.keys()
# Out:
# ['/Users/cjw/Data/cyto/zf_sorted/Sorted_SortedFish2.mm', '/Users/cjw/Data/cyto/zf_sorted/Sorted_SortedFish3.mm', '/Users/cjw/Data/cyto/zf_sorted/Sorted_SortedFish1.mm']
# 28031
# dict_keys(['Sorted_SortedFish2.mm', 'Sorted_SortedFish3.mm', 'Sorted_SortedFish1.mm'])

# %%
n = xshape[0]
all_ids =  range(n_all_images)
idx = 0
dataframes = list()
for key in mmdict.keys():
    mm = mmdict[key]
    n = mm.shape[0]
    #print(n)
    file = n*[key[0:-3].lower()]
    fid = range(n)
    mmfile = n*[key]
    plate = n*[0]
    row = n*[0]
    column = n*[0]
    field = n*[0]
    yc = n*[32]
    xc = n*[32]
    well = n*[0]
    ids = all_ids[idx:idx + n]
    idx += n
    xdf = pd.DataFrame({'id':ids, 'fid':fid, 'file':file, 'mmfile':mmfile, 'plate':plate,
                     'row':row, 'column':column, 'field':field,
                      'yc':yc, 'xc':xc, 'well':well})

    dataframes.append(xdf)
    
alldf = pd.concat(dataframes, ignore_index=True)
trts = list()
runs = list()

for row in range(len(alldf)):
    file = alldf.iloc[row]['file']
    if '_ice' in file.lower():
        treatment = 'ice'
    elif '_ccb'in file.lower():
        treatment = 'ccb'
    else:
        treatment = "untreated"
    trts.append(treatment)
    runs.append(file[0:5])

alldf['treatment'] = trts
alldf['run'] = runs
alldf.head()
# Out:
#    id  fid                file                 mmfile  plate  row  column  \
# 0   0    0  sorted_sortedfish2  Sorted_SortedFish2.mm      0    0       0
# 1   1    1  sorted_sortedfish2  Sorted_SortedFish2.mm      0    0       0
# 2   2    2  sorted_sortedfish2  Sorted_SortedFish2.mm      0    0       0
# 3   3    3  sorted_sortedfish2  Sorted_SortedFish2.mm      0    0       0
# 4   4    4  sorted_sortedfish2  Sorted_SortedFish2.mm      0    0       0
#
#    field  yc  xc  well  treatment    run
# 0      0  32  32     0  untreated  sorte
# 1      0  32  32     0  untreated  sorte
# 2      0  32  32     0  untreated  sorte
# 3      0  32  32     0  untreated  sorte
# 4      0  32  32     0  untreated  sorte

# %%
def mapname(name):
    s = name.split("_")
    j = "sorted_sorted" + s[1]
    return j.lower()

udpath = '/Users/cjw/Projects/cjw/cyto/Clustering/ZebraFish_Sorted/UserDefined/clusters.pkl'
dlpath ='/Users/cjw/Projects/cjw/cyto/Clustering/ZebraFish_Sorted/DeepLearning/clusters.pkl'
clustermap = pd.read_pickle(udpath)

print(clustermap.head())
clustermap = clustermap.rename(index=str, columns={"File Name":"file", "Index in File":'fid', 'ClusterID':'cid_ud'})
clustermap['file'] = clustermap['file'].map(mapname)
alldf['file'] = alldf['file'].str.lower()
print(clustermap.head())
print(alldf.head())
print('----')
alldf = alldf.merge(clustermap, on=['file', 'fid'])
print('AllDF', alldf.head())
print(clustermap.head())

myclustermap = pd.read_pickle(dlpath)
myclustermap = myclustermap.rename(index=str, columns={"File Name":"file", "Index in File":'fid', 'ClusterID':'cid_dl'})
myclustermap['file'] = myclustermap['file'].str.lower()                                     
print(myclustermap.head())
alldf = alldf.merge(myclustermap, on=['file', 'fid'])
print(len(alldf))
print(alldf.head())
# Out:
#    ClusterID                  File Name  Index in File
# 0       4657  sorted_Fish1_10_processed              8
# 1       4657  sorted_Fish1_10_processed             17
# 2       4657  sorted_Fish1_10_processed             21
# 3       4657  sorted_Fish1_10_processed             22
# 4       4657  sorted_Fish1_10_processed             27
#    cid_ud                file  fid
# 0    4657  sorted_sortedfish1    8
# 1    4657  sorted_sortedfish1   17
# 2    4657  sorted_sortedfish1   21
# 3    4657  sorted_sortedfish1   22
# 4    4657  sorted_sortedfish1   27
#    id  fid                file                 mmfile  plate  row  column  \
# 0   0    0  sorted_sortedfish2  Sorted_SortedFish2.mm      0    0       0
# 1   1    1  sorted_sortedfish2  Sorted_SortedFish2.mm      0    0       0
# 2   2    2  sorted_sortedfish2  Sorted_SortedFish2.mm      0    0       0
# 3   3    3  sorted_sortedfish2  Sorted_SortedFish2.mm      0    0       0
# 4   4    4  sorted_sortedfish2  Sorted_SortedFish2.mm      0    0       0
#
#    field  yc  xc  well  treatment    run
# 0      0  32  32     0  untreated  sorte
# 1      0  32  32     0  untreated  sorte
# 2      0  32  32     0  untreated  sorte
# 3      0  32  32     0  untreated  sorte
# 4      0  32  32     0  untreated  sorte
# ----
# AllDF    id  fid                file                 mmfile  plate  row  column  \
# 0   0    0  sorted_sortedfish2  Sorted_SortedFish2.mm      0    0       0
# 1   1    1  sorted_sortedfish2  Sorted_SortedFish2.mm      0    0       0
# 2   2    2  sorted_sortedfish2  Sorted_SortedFish2.mm      0    0       0
# 3   3    3  sorted_sortedfish2  Sorted_SortedFish2.mm      0    0       0
# 4   4    4  sorted_sortedfish2  Sorted_SortedFish2.mm      0    0       0
#
#    field  yc  xc  well  treatment    run  cid_ud
# 0      0  32  32     0  untreated  sorte    4656
# 1      0  32  32     0  untreated  sorte    4657
# 2      0  32  32     0  untreated  sorte    4657
# 3      0  32  32     0  untreated  sorte    4661
# 4      0  32  32     0  untreated  sorte    4656
#    cid_ud                file  fid
# 0    4657  sorted_sortedfish1    8
# 1    4657  sorted_sortedfish1   17
# 2    4657  sorted_sortedfish1   21
# 3    4657  sorted_sortedfish1   22
# 4    4657  sorted_sortedfish1   27
#    cid_dl                file  fid
# 0   39166  sorted_sortedfish1    7
# 1   39166  sorted_sortedfish1   13
# 2   39166  sorted_sortedfish1   16
# 3   39166  sorted_sortedfish1   18
# 4   39166  sorted_sortedfish1   24
# 28031
#    id  fid                file                 mmfile  plate  row  column  \
# 0   0    0  sorted_sortedfish2  Sorted_SortedFish2.mm      0    0       0
# 1   1    1  sorted_sortedfish2  Sorted_SortedFish2.mm      0    0       0
# 2   2    2  sorted_sortedfish2  Sorted_SortedFish2.mm      0    0       0
# 3   3    3  sorted_sortedfish2  Sorted_SortedFish2.mm      0    0       0
# 4   4    4  sorted_sortedfish2  Sorted_SortedFish2.mm      0    0       0
#
#    field  yc  xc  well  treatment    run  cid_ud  cid_dl
# 0      0  32  32     0  untreated  sorte    4656   39166
# 1      0  32  32     0  untreated  sorte    4657   39165
# 2      0  32  32     0  untreated  sorte    4657   39160
# 3      0  32  32     0  untreated  sorte    4661   39160
# 4      0  32  32     0  untreated  sorte    4656   39165

# %%
len(alldf)
# Out:
# 28031

# %%
alldf.head(), alldf['mmfile'].unique()
# Out:
# (   id  fid                file                 mmfile  plate  row  column  \
#  0   0    0  sorted_sortedfish2  Sorted_SortedFish2.mm      0    0       0
#  1   1    1  sorted_sortedfish2  Sorted_SortedFish2.mm      0    0       0
#  2   2    2  sorted_sortedfish2  Sorted_SortedFish2.mm      0    0       0
#  3   3    3  sorted_sortedfish2  Sorted_SortedFish2.mm      0    0       0
#  4   4    4  sorted_sortedfish2  Sorted_SortedFish2.mm      0    0       0
#
#     field  yc  xc  well  treatment    run  cid_ud  cid_dl
#  0      0  32  32     0  untreated  sorte    4656   39166
#  1      0  32  32     0  untreated  sorte    4657   39165
#  2      0  32  32     0  untreated  sorte    4657   39160
#  3      0  32  32     0  untreated  sorte    4661   39160
#  4      0  32  32     0  untreated  sorte    4656   39165  ,
#  array(['Sorted_SortedFish2.mm', 'Sorted_SortedFish3.mm',
#         'Sorted_SortedFish1.mm'], dtype=object))

# %%
c_df = pd.pivot_table(alldf, values='xc', index=['cid_ud'],
                      columns=['cid_dl'], aggfunc='count').reset_index('cid_ud')
c_df = c_df.fillna(0)

#print(c_df)
#print(c_df.index, type(c_df.index))
mc_df = c_df.melt(id_vars=('cid_ud'))
mc_df = mc_df.fillna(0)
mc_df['value'] = (mc_df['value']/5.)#.astype(np.float64)
mc_df = mc_df.fillna(0)
#print(mc_df)
#plt.figure(figsize=(12,12))

# %%
import holoviews as hvv
hvv.extension('matplotlib')
#%output size=350
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
#   margin-bottom: 0.5em;
# }
#
# div.hologroup {
#   padding-left: 0;
#   padding-right: 0.8em;
#   width: 100%;
# }
#
# .holoselect {
#   width: 92%;
#   margin-left: 0;
#   margin-right: 0;
# }
#
# .holotext {
#   padding-left:  0.5em;
#   padding-right: 0;
#   width: 100%;
# }
#
# .holowidgets .ui-resizable-se {
#   visibility: hidden
# }
#
# .holoframe > .ui-resizable-se {
#   visibility: hidden
# }
#
# .holowidgets .ui-resizable-s {
#   visibility: hidden
# }
#
#
# /* CSS rules for noUISlider based slider used by JupyterLab extension  */
#
# .noUi-handle {
#   width: 20px !important;
#   height: 20px !important;
#   left: -5px !important;
#   top: -5px !important;
# }
#
# .noUi-handle:before, .noUi-handle:after {
#   visibility: hidden;
#   height: 0px;
# }
#
# .noUi-target {
#   margin-left: 0.5em;
#   margin-right: 0.5em;
# }
# </style>
#
#
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>

# %%
# %%opts Sankey (cmap='Blues', edge_cmap='Blues')
# %%output filename="/Users/cjw/sankey_rop.svg" fig='svg'
# %output size=200
# def f(h):
#     return "{:8.1f}".format(h)
#
# nx = list(mc_df['cid_ud'].unique())
# ny = list(mc_df['cid_dl'].unique())
# nodes = list()
# nodes.extend(nx)
# nodes.extend(ny)
# nodes = hvv.Dataset(enumerate(nodes), ['User Defined', 'AutoEncoder'])
# edges = [tuple(x) for x in mc_df.itertuples(index=False)]
# #print(nodes)
# #print(edges[0])
# # hv.Sankey(mc_df).options(label_position='left',
# #                          width=600, height=800,
# #                          edge_color_index='clusterId_x')
# value_dim = hvv.Dimension('Mean', value_format=f)
# #plt.figure(figsize=(4,4))
# hvv.Sankey((edges, nodes), ['UD', 'AE'], vdims=value_dim).options(label_position='left',
#                                                                  aspect=.6,
#                          #width=600, height=800, label_index='AutoEncoder',
#                          edge_color_index='AE')
# Out:
# :Sankey   [UD,AE]   (Mean)

# %%
# %matplotlib inline
from sklearn.preprocessing import normalize
p_df = pd.pivot_table(alldf, values='xc', index=['clusterId_x'], columns=['clusterId_y'], aggfunc='count')
p_df = p_df.fillna(0)
plt.figure(figsize=(12,18))
v = p_df.values
v0 = normalize(v, axis=0, norm='max')
print(np.sum(v, axis=0), np.sum(v, axis=0).shape)
print(np.sum(v0, axis=0), np.sum(v0, axis=0).shape)
print(np.sum(v0, axis=1), np.sum(v0, axis=1).shape)
v1 = normalize(v, axis=1, norm='max')
print(np.sum(v1, axis=0), np.sum(v1, axis=0).shape)
print(np.sum(v1, axis=1), np.sum(v1, axis=1).shape)
plt.subplot(2,1,1)
sns.heatmap(v1, square=True, xticklabels=p_df.columns, yticklabels=p_df.index, cmap="RdYlBu_r",
           linewidth=.5, linecolor='black', robust=True)
plt.xticks(rotation=60)
plt.yticks(rotation=0)
plt.subplot(2,1,2)
sns.heatmap(v0, square=True, xticklabels=p_df.columns, yticklabels=p_df.index, cmap="RdYlBu_r",
           linewidth=.5, linecolor='black', robust=True)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
# Out:
# [ 8987.  9716.  7001. 15789.   956.  1713.  9759. 32481.   288.  3412.
#   1724.  9140.  1989.  3953.  1033.  2806.  1271.  1768.   627.  2780.
#  13226.  1062.   305.  4072. 28742.   173.   112.  4714.] (28,)
# [1.79309657 1.65915301 1.65664931 4.30452563 3.12418301 4.74515235
#  1.99570552 1.81003065 3.46987952 3.08499096 1.76820513 3.5385211
#  4.0509165  1.76709879 2.56327543 1.75594493 3.2757732  2.09976247
#  2.91627907 1.82414698 3.76166098 2.19875776 3.38888889 3.26805778
#  1.99154656 3.14545455 2.43478261 4.00509771] (28,)
# [2.79378823 1.96169984 5.72090288 1.24642378 0.95137538 1.20975849
#  2.18462257 5.47568389 0.07833712 1.36819707 2.31076332 0.75463879
#  0.27075499 0.42346371 0.71198787 2.65106093 5.96458181 4.18306323
#  2.9422903  0.74710368 0.17919894 7.53494638 9.31662552 5.11939841
#  1.50381934 9.79305048] (26,)
# [2.77413067 4.01445451 2.27306704 6.48092829 0.47136684 0.68338467
#  4.87906965 7.12611226 0.14423302 0.95598782 0.33635811 5.03482341
#  0.86414351 0.98194154 0.62559956 0.69378205 0.53374194 0.8436775
#  0.23938931 1.2904874  4.5539985  0.4183732  0.15741673 2.16837565
#  6.2289135  0.09510525 0.05688704 1.79260199] (28,)
# [2.36350148 1.45196403 1.84537969 1.82850431 1.94563919 1.27048023
#  1.22299524 3.61711385 1.50584795 2.49222798 1.70804911 3.28531856
#  1.55836342 1.7518797  1.25505618 1.8903143  1.82462253 2.55822077
#  3.25016545 2.65510597 2.70909091 2.04455377 2.95081967 3.21700796
#  2.46118299 2.05494567] (26,)
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5, 18.5, 19.5, 20.5, 21.5,
#         22.5, 23.5, 24.5, 25.5]), <a list of 26 Text yticklabel objects>)

# %%
plt.figure(figsize=(14,14))

sns.heatmap(v, square=True, xticklabels=p_df.columns, yticklabels=p_df.index, cmap="RdYlBu_r",
           linewidth=.5, linecolor='black', robust=True)
plt.xticks(rotation=60)
plt.yticks(rotation=0)
np.sum(v)
# Out:
# 169599.0

# %%
from scipy.spatial import distance_matrix
from scipy.spatial.distance import pdist, cdist

dm =  np.arccos(1 -cdist(g_all,g_all, metric='cosine'))
#dm =  cdist(g_all, g_all, metric='euclidean')
#dm = distance_matrix(mma, mma)
print(dm.shape)

ddict = dict()
for i in range(g_all.shape[0]):
    ri = np.argsort(dm[i])
    ddict[i] = ri[1:13]

dm[1,ddict[1]]
# Out:
# (4500, 4500)
# array([0.84650457, 0.89392709, 0.92158811, 0.95054435, 0.95505369,
#        0.96474147, 0.98575274, 0.99417142, 1.00281157, 1.01690594,
#        1.0258913 , 1.0268415 ])

# %%
from sklearn.metrics import silhouette_score, calinski_harabaz_score

sc = silhouette_score(dm, labels=gm, metric='precomputed', sample_size=None)
ch = calinski_harabaz_score(g_all, gm)
sc, ch
# Out:
# (0.02651123624465178, 33.53769632381485)

# %%
from matplotlib.colors import ListedColormap
from sklearn import neighbors
